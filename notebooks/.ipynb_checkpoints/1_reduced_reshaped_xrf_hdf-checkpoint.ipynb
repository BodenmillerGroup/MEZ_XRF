# %% [markdown]
# # 1. Preprocessing of XRF hdf files
# ## Summary
# This notebook reduces the raw .hdf XRF files collected at the ID15A beamline (European Synchrotron Radiation Facility) to pre-processed hdf files. These pre-processed hdf files have a consistent dataset naming strategy and contain only the datasets required to produce deconvoluted 2D XRF data. Datasets in pre-processed datasets include:
# 1. stage coordinates
#     + hrz (z position)
#     + hry (y position)
# 2. spectra per pixel
#     + falconx_det0 (detector 1)
#     + fluodet_det0 (detector 2, used in some scans)
# 3. beam flux measurements local to the sample environment collected at the time interval trigger (for normalisation of XRF spectra intensities)
#     + fpico3
#
# ### Stitching
# As well as reducing hdf datasets to a consistent format, this notebook can stitch together fragmented scans (scans formed by multiple scans). For all scans then:
# + Complete scans are reduced to the key datasets needed for 2D XRF mapping
# + Incomplete scans that need to be stitched together are stitched then reduced to the key datasets needed for 2D XRF mapping.
#     This requires that:
#     1. Scans to be stitched have at least 1 row of scan overlap (the notebook will detect this via row coordinates stored in the `hrz` dataset of raw hdf files)
#     2. Scans to be stitched together are identified in `xrf_scan_metadata.csv` in a `scanset` column, where scans that need to be stitched together have a common (unique) name.
#
# All reduced .hdf files are output to `data/processed/xrf/1_reduced_reshaped`.
#
# Output reduced .hdf files are suitable for further processing, including flux normalisation (see notebook 2) or straight deconvolution (see notebook 3) to generate per channel images.

# %%
import pathlib
import numpy as np
import pandas as pd
import h5py

# %% [markdown]
# ### Set up folder structure
# The following cell sets up the folder structure required. Only the base directory may need modifying.
#
# In the base directory, if a raw subdirectory does not exist it will be made. This raw subdirectory should contain the raw .hdf files of interest and `xrf_scan_metadata.csv`. Within `xrf_scan_metadata.csv`, a column listing the filepath to each raw .hdf file of interest is required.
#
# A processed subdirectory will be made for the stitched .hdf files.

# %%
# Define base directory to work from 
base_dir = "C:/Users/MerrickS/OneDrive/Work/2_UZH/Papers/1_MEZ_XRF"
base_dir = pathlib.Path(base_dir)

# Make raw directory for raw hdf files if it does not exist
input_dir = base_dir / 'data' / 'raw' / 'xrf'
input_dir.mkdir(parents=True, exist_ok=True)

# Make output directory for reshaped hdf files if it does not exist
out_dir = base_dir / 'data' / 'processed' / 'xrf' / '1_reduced_reshaped_hdfs'
out_dir.mkdir(parents=True, exist_ok=True)
print('Reshaped hdf files output to: \t', out_dir)
# Out:
# Reshaped hdf files output to: 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs

# %% [markdown]
# ### Select raw datasets to include in pre-processed hdf files
# Specify which datasets to copy from raw data to pre-processed hdf datasets. Datasets will be stored as dictionary keys to which values are ascribed prior to saving into the preprocessed hdf file.

# %%
# Name the hdf parameters to extract and incorpate into new stitched hdf file (can add
# extras here if look at the keys in hdf)
hdf_datasets = ['1.1/measurement/hrz',
                '1.1/measurement/hry',
                '1.1/measurement/fpico3',
                '1.1/measurement/falconx_det0',
                '1.1/measurement/fluodet_det0',
                ]

# Convert datasets list to a dictionary (no values at this point)
hdf_datasets = dict.fromkeys(hdf_datasets)

# Make a dataframe to track preprocessed scans and scansets with deconvolution configs
preprocessed_files_cols = ['hdf_file', 'config_file', 'step_um', 'dual_detector']
df_preprocessed_files = pd.DataFrame(columns = preprocessed_files_cols)

# %% [markdown]
# ### Identify scans to process
# Import a .csv spreadsheet named `xrf_scan_metadata.csv` from the /data/raw/xrf/ subdirectory. This .csv list all scans of interest and identifies which scans need to be stitched together.
#
# `xrf_scan_metadata.csv` should include
# 1. A `scan_name` column which will be used to name the pre-processed dataset
# 2. A `hdf_filepath` column that points to the raw data location relative to the base directory.
# 3. A `scanset` column that identifies scans to be stitched together as those scans with the same scanset name. The scanset name will be used to name the file
#
# The next cell collects filepaths, files, filenames to be processed.

# %%
#   Get .hdf scan names and paths from hdf_filepath supplied in raw metadata csv
df_hdf_metadata = pd.read_csv(input_dir / 'xrf_scan_metadata.csv')

# Make a dataframe of paths, files and fnames from hdf_filepath to include in 'xrf_scan_metadata_full.csv'
full_fpaths = []
paths = []
files = []
fnames = []
for hdf_fn in df_hdf_metadata['hdf_file'][:]:
    hdf_filepath = list(input_dir.glob(f'**/*/{hdf_fn}'))[0]    
    fullpath = hdf_filepath
        
    full_fpaths.append(fullpath)
    paths.append(hdf_filepath.parent)
    files.append(hdf_filepath.name)
    fnames.append(hdf_filepath.stem)   

df_hdf_metadata['hdf_full_fpaths'] = full_fpaths
df_hdf_metadata['hdf_path'] = paths
df_hdf_metadata['hdf_file'] = files
df_hdf_metadata['hdf_filename'] = fnames

df_hdf_metadata.to_csv((out_dir / 'xrf_scan_metadata_full.csv'), index=False)

# check hdf files exist
for filepath in full_fpaths:
    if filepath.exists() == True:
        pass
    else:
        print ("\t !!!File does not exist!!!:", fullpath)

# %% [markdown]
#  The next cell identifies complete scans and scansets from the imported csv.

# %%
# Get complete scans
df_complete_scans = df_hdf_metadata[df_hdf_metadata['scanset'].isnull()]
complete_scans = df_complete_scans['hdf_filename'].unique().tolist()
print('\n', len(complete_scans), 'complete scans identified for reduction:')    
for scan in complete_scans: print('\t', scan)

# Get incomplete scans that are part of a scanset to stitch
df_scansets = df_hdf_metadata[df_hdf_metadata['scanset'].notnull()]
scansets = df_scansets['scanset'].unique().tolist() # scansets unique names

print('\n', len(scansets), 'scansets identified for stitching and reduction from metadata:')    
for scanset in scansets: print('\t',scanset)

hdfs_to_stitch = [] # list of scans for each scanset
for scanset in scansets:
    scanset_scans = df_scansets.hdf_filename[df_scansets['scanset'] == scanset].to_list()
    hdfs_to_stitch.append(scanset_scans)
    
# Turn scansets to a dictionary for each scanset (keys) of .hdfs (values) 
# that need stitching
scansets = dict(zip(scansets, hdfs_to_stitch)) 

print('\n Scan names for scansets listed in \'scansets\' dictionary')
# Out:
#  226 complete scans identified for reduction:
# 	 sample191_0001
# 	 mylar_0001
# 	 sample107_t_0001
# 	 sample107_b_0001
# 	 sample105_t_0001
# 	 sample105_b_0001
# 	 sample103_t_0001
# 	 sample103_b_0001
# 	 sample102_t_0001
# 	 sample102_b_0001
# 	 axo_thin_film_c00_0005
# 	 sample001_0001
# 	 sample001_0003
# 	 AXO_thin_film_C00_006_0006
# 	 sample304_0013
# 	 sample304_0016
# 	 sample304_0017
# 	 sample304_0018
# 	 AXO_thin_film_3_0001
# 	 AXO_thin_film_3_0002
# 	 AXO_thin_film_3_0003
# 	 sample102_t_3_0001
# 	 sample102_t_3_0002
# 	 sample102_t_3_0003
# 	 sample102_t_3_0004
# 	 sample102_t_3_0005
# 	 sample102_t_3_0006
# 	 sample103_t_3_0001
# 	 sample103_t_3_0002
# 	 sample103_t_3_0003
# 	 sample103_t_3_0004
# 	 sample103_t_3_0005
# 	 sample103_t_3_0006
# 	 sample105_t_3_0001
# 	 sample105_t_3_0002
# 	 sample105_t_3_0003
# 	 sample105_t_3_0004
# 	 sample105_t_3_0005
# 	 sample105_t_3_0006
# 	 sample107_t_3_0001
# 	 sample107_t_3_0002
# 	 sample107_t_3_0003
# 	 sample107_t_3_0004
# 	 sample107_t_3_0005
# 	 sample107_t_3_0006
# 	 GeCMOS_blank_1000
# 	 GeCMOS_blank_100
# 	 GeCMOS_blank_10
# 	 sample304_0001
# 	 sample304_0002
# 	 sample304_b_0001
# 	 sample304_b_0002
# 	 sample304_b_0003
# 	 sample304_b_0004
# 	 st_cp_column2_aglfxd_2_10Hz_0001
# 	 st_cp_column2_aglfxd_50Hz_0002
# 	 st_cp_column2_angle_250Hz_0002
# 	 st_cp_1_column1_10Hz_0001
# 	 st_cp_column1_50Hz_0001
# 	 st_cp_column1_250Hz_0001
# 	 st_cp_1_column1_10Hz_0002
# 	 st_cp_column1_50Hz_0002
# 	 st_cp_column1_250Hz_0002
# 	 st_cp_column2_aglfxd_10Hz_0001
# 	 st_cp_column2_aglfxd_50Hz_0001
# 	 st_cp_column2_angle_250Hz_0001
# 	 bl_cp_column2_10Hz_0002
# 	 bl_cp_column2_50Hz_0002
# 	 bl_cp_column2_250Hz_0004
# 	 bl_cp_column1_10Hz_0001
# 	 bl_cp_column1_50Hz_0001
# 	 bl_cp_column1_250Hz_0001
# 	 bl_cp_skbr3re_10Hz_0001
# 	 bl_cp_skbr3re_50Hz_0001
# 	 bl_cp_skbr3re_250Hz_0001
# 	 bl_cp_column2_10Hz_0001
# 	 bl_cp_column2_50Hz_0001
# 	 bl_cp_column2_250Hz_0003
# 	 sp_cp_column2_10Hz_0002
# 	 sp_cp_column2_50Hz_0002
# 	 sp_cp_column2_250Hz_0002
# 	 sp_cp_a431real_500Hz_0001
# 	 sp_cp_a431real_800Hz_0001
# 	 sp_cp_a431real_1000Hz_0001
# 	 sp_cp_a431real_1500Hz_0001
# 	 sp_cp_column1_10Hz_0001
# 	 sp_cp_column1_50Hz_0001
# 	 sp_cp_column1_250Hz_0001
# 	 sp_cp_mcf10a_500Hz_0001
# 	 sp_cp_mcf10a_800Hz_0001
# 	 sp_cp_mcf10a_1000Hz_0001
# 	 sp_cp_mcf10a_1500Hz_0001
# 	 sp_cp_column1_10Hz_0002
# 	 sp_cp_column1_50Hz_0002
# 	 sp_cp_column1_250Hz_0002
# 	 sp_cp_skbr3_500Hz_0001
# 	 sp_tt_skbr3_800Hz_0001
# 	 sp_tt_skbr3_1000Hz_0001
# 	 sp_cp_skbr3_1500Hz_0002
# 	 sp_cp_column2_10Hz_0001
# 	 sp_cp_column2_50Hz_0001
# 	 sp_cp_column2_250Hz_0001
# 	 sp_cp_a431_500Hz_0001
# 	 sp_cp_a431_800Hz_0001
# 	 sp_cp_a431_1000Hz_0001
# 	 sp_cp_zr751_1500Hz_0002
# 	 st_tt_h2_inset_10Hz_0002
# 	 st_tt_h2lb2_50Hz_0001
# 	 st_tt_h2lb2_250Hz_0001
# 	 st_tt_hl4_inset_10Hz_0001
# 	 st_tt_hl4_inset_50Hz_0002
# 	 st_tt_hl4_250Hz_0001
# 	 st_tt_lb2_inset_10Hz_0001
# 	 st_tt_h2lb2_50Hz_0002
# 	 st_tt_h2lb2_250Hz_0002
# 	 st_tt_lbh4_inset_10Hz_0001
# 	 st_tt_lbh4_inset_50Hz_0001
# 	 st_tt_lbh4_250Hz_0001
# 	 bl_tt_h2_inset_10Hz_0002
# 	 bl_tt_h2_50Hz_0001
# 	 bl_tt_h2_250Hz_0001
# 	 bl_tt_lb2_inset1_10Hz_0001
# 	 bl_tt_lb2_50Hz_0001
# 	 bl_tt_lb2_250Hz_0001
# 	 bl_tt_lbh4_inset_10Hz_0001
# 	 bl_tt_lbh4_50Hz_0001
# 	 bl_tt_lbh4_250Hz_0001
# 	 sp_tt_h2_inset_10Hz_0001
# 	 sp_tt_h2_inset_50Hz_0001
# 	 sp_tt_h2_250Hz_0001
# 	 sp_tt_h2_500Hz_0001
# 	 sp_tt_lb2h2_800Hz_0002
# 	 sp_tt_hl4_inset_50Hz_0001
# 	 sp_tt_hl4_250Hz_0001
# 	 sp_tt_lb2_inset_50Hz_0001
# 	 sp_tt_lb2_250Hz_0001
# 	 sp_tt_lb2_500Hz_0001
# 	 sp_tt_lb2h2_800Hz_0001
# 	 sp_tt_lbh4_inset_50Hz_0001
# 	 sp_tt_lbh4_250Hz_0001
# 	 sp_tt_lbh4_500Hz_0001
# 	 sp_tt_lbh4_800Hz_0001
# 	 sp_tt_h2_step25_800Hz_0001
# 	 sp_tt_lbh4_step25_50Hz_0001
# 	 sp_tt_lbh4_step25_250Hz_0001
# 	 sp_tt_lbh4_step25_500Hz_0001
# 	 sp_tt_lbh4_step25_800Hz_0001
# 	 g102t_10Hz_0004
# 	 g102t_50Hz_0004
# 	 g102t_250Hz_0004
# 	 g102t_500Hz_0001
# 	 g102t_800Hz_0001
# 	 g102t_1000Hz_0001
# 	 g102b_10Hz_0001
# 	 g102b_50Hz_0001
# 	 g102b_250Hz_0002
# 	 g102b_500Hz_0001
# 	 g102b_800Hz_0001
# 	 g102b_1000Hz_0001
# 	 g104t_10Hz_0001
# 	 g104t_50Hz_0001
# 	 g104t_250Hz_0001
# 	 g104t_500Hz_0001
# 	 g104t_800Hz_0001
# 	 g104t_1000Hz_0001
# 	 g104b_10Hz_0001
# 	 g104b_50Hz_0001
# 	 g104b_250Hz_0001
# 	 g104b_500Hz_0001
# 	 g104b_800Hz_0001
# 	 g104b_1000Hz_0001
# 	 g106t_10Hz_0001
# 	 g106t_50Hz_0002
# 	 g106t_250Hz_0001
# 	 g106t_500Hz_0001
# 	 g106t_800Hz_0001
# 	 g106t_1000Hz_0001
# 	 g106b_10Hz_0001
# 	 g106b_50Hz_0001
# 	 g106b_250Hz_0001
# 	 g106b_500Hz_0001
# 	 g106b_800Hz_0001
# 	 g106b_1000Hz_0001
# 	 g108t_10Hz_0001
# 	 g108t_50Hz_0001
# 	 g108t_250Hz_0001
# 	 g108t_500Hz_0001
# 	 g108t_800Hz_0001
# 	 g108t_1000Hz_0001
# 	 g108b_10Hz_0001
# 	 g108b_50Hz_0001
# 	 g108b_250Hz_0001
# 	 g108b_500Hz_0001
# 	 g108b_800Hz_0001
# 	 g108b_1000Hz_0001
# 	 g192_10Hz_0001
# 	 g192_50Hz_0001
# 	 g192_250Hz_0001
# 	 g192_500Hz_0001
# 	 g192_800Hz_0002
# 	 g192_1000Hz_0001
# 	 g194_10Hz_0001
# 	 g194_50Hz_0001
# 	 g194_250Hz_0001
# 	 g194_500Hz_0001
# 	 g194_800Hz_0001
# 	 g194_1000Hz_0001
# 	 blank_tower_10Hz_0001
# 	 blank_tower_50Hz_0001
# 	 blank_tower_250Hz_0001
# 	 blank_tower_500Hz_0001
# 	 blank_tower_800Hz_0001
# 	 blank_tower_1000Hz_0001
# 	 blank_env_10Hz_0001
# 	 blank_env_50Hz_0001
# 	 blank_env_250Hz_0001
# 	 blank_env_500Hz_0001
# 	 blank_env_800Hz_0001
# 	 blank_env_1000Hz_0001
# 	 appendix_a1_overview_solid_0002
# 	 appendix_a1_ROI_solid_0001
# 	 tonsil_t1_overview_solid_0001
# 	 tonsil_t1_ROI_solid_0001
# 	 breast_cancer_b2_solid_overview_0corrected_0003
# 	 breast_cancer_b2_ROI_solid_ROI_0001
# 	 breast_cancer_b2_ROI_solid_0003
#
#  4 scansets identified for stitching and reduction from metadata:
# 	 001_002_stitch
# 	 001_004_stitch
# 	 304_007_stitch
# 	 304_009_stitch
#
#  Scan names for scansets listed in 'scansets' dictionary

# %% [markdown]
# ### Hdf dataset crop functions
# Load functions needed to define crop dimensions for scansets.

# %%
#%% This function returns the hrz (number of rows and their coordinates) 
#   for a specified hdf file
def hdf_hrz_list(hdf_filepath): 
    with h5py.File(hdf_filepath, 'r') as hdf:
        hrz_list = list(hdf['1.1/measurement/hrz'])
    return hrz_list

#%% This function extracts the named dataset from an hdf file as an hdf dataset
def hdf_dataset(hdf_filepath, dataset): 
    with h5py.File(hdf_filepath, 'r') as hdf:
        node = f"{dataset}"
        try:
            hdf[node]
            #print(f'{node} exists')       
            dset = hdf[f'{dataset}']
        except KeyError:
            print(f'\t !!! {node} does not exist, could not retrieve dataset')
            dset = []
        dset = dset[:]
    return dset

#%% This function identifies the  overlapping rows in a list of hdf5 
#   consecutive scans. It returns a list of lengths by which to crop data 
#   within overlapping scans. This crop_list can be used to slice overlapping
#   scans so they are suitable to stitch together.
def hdf_list_crop(hdf_filepaths):  
    scan_number = len(hdf_filepaths)
    
    # Make a list of hrz position lists
    z_pos = []
    y_cols = []
    for scan in hdf_filepaths:
        scan_filepath = base_dir / scan
        
        with h5py.File(scan_filepath, 'r') as hdf_initialise:
            hdf_z_pos = hdf_hrz_list(scan_filepath)

            # in some .hdfs, the fscan parameters are not recorded, so column number must be calculated
            node = '1.1/instrument/fscan_parameters/fast_npoints'              
            try:
                ycols_in_scan = hdf_initialise[node][()]
            except KeyError:
                ycols_in_scan = hdf_z_pos.count(hdf_z_pos[0]) # get number of columns in a row, by counting number of z_pos in first row       

        z_pos.append(hdf_z_pos)
        y_cols.append(ycols_in_scan) # get number of columns in a row, by counting number of z_pos in first row
        print(f'\t Scan: {scan} \n\t has {len(set(hdf_z_pos))} rows & {y_cols[-1]} columns')
        
    # Check scans have the same number of columns that can be stitched
    if y_cols.count(y_cols[0]) == len(y_cols):
        y_cols = y_cols[0]
        print(f'\t Same number of columns in each scan so scanset {scanset} suitable for stitching',
              f'\n\t Proceeding to determine crop dimensions for {scanset}')
    else:
        print(f'\t Different number of columns in each scan',
              f'\n\t Scanset {scanset} cannot be stitched')
    
    # Get hrz rows overlap for successive scans
    z_overlap_rows = []
    for scan in range(scan_number-1): #check overlap between scan pairs, except last scan
        z_overlap = list((set(z_pos[scan])).intersection(set(z_pos[scan+1])))
        z_overlap_rows.append(len(z_overlap))
        print(f'\t Scan {scan+1} overlaps with scan {scan+2} by {z_overlap_rows[-1]} rows.')
        print(f'\t Last {z_overlap_rows[-1]} rows will be dropped from scan {scan+1} in crop list')
    z_overlap_rows.append(0)
        
    # Length of datapoints to keep from each hdf file
    crop_list = []
    for scan, value in enumerate(z_pos):
        rows = len(set(value))
        crop_list.append((rows-z_overlap_rows[scan])*y_cols)
                
    return crop_list

def scannames_to_filepaths(scans):
    filepaths = []
    for scan in scans:
        filepath = df_hdf_metadata.loc[df_hdf_metadata['hdf_filename'] == scan, 'hdf_full_fpaths'].iloc[0]
        filepaths.append(filepath)
    return filepaths

# %% [markdown]
# ### Get scanset crop dimensions
# For identified scansets, define how to crop scans within a scanset to stitch together.
#
# Scanset crop dimensions will be stored as a `crop_dict` dictionary, with scanset name as key and crop dimensions as value.

# %%
crop_dict = {}
for scanset in scansets:
    print(f'Scanset {scanset}:')
    hdf_filepaths = scannames_to_filepaths(scansets[scanset])
    crop_dict.update({scanset:hdf_list_crop(hdf_filepaths)})
           
print('\n\n Crop dimensions for scansets')
for scanset in scansets:
    print('\t', scanset, 'crop dimensions', crop_dict[scanset])

print('\n\n All scanset crop dimensions identified')
# Out:
# Scanset 001_002_stitch:
# 	 Scan: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0002\sample001_0002.h5
# 	 has 84 rows & 200 columns
# 	 Scan: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0002cont\sample001_0002cont.h5
# 	 has 118 rows & 200 columns
# 	 Same number of columns in each scan so scanset 001_002_stitch suitable for stitching
# 	 Proceeding to determine crop dimensions for 001_002_stitch
# 	 Scan 1 overlaps with scan 2 by 1 rows.
# 	 Last 1 rows will be dropped from scan 1 in crop list
# Scanset 001_004_stitch:
# 	 Scan: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0004\sample001_0004.h5
# 	 has 131 rows & 200 columns
# 	 Scan: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0005\sample001_0005.h5
# 	 has 70 rows & 200 columns
# 	 Same number of columns in each scan so scanset 001_004_stitch suitable for stitching
# 	 Proceeding to determine crop dimensions for 001_004_stitch
# 	 Scan 1 overlaps with scan 2 by 1 rows.
# 	 Last 1 rows will be dropped from scan 1 in crop list
# Scanset 304_007_stitch:
# 	 Scan: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0007\sample304_0007.h5
# 	 has 338 rows & 400 columns
# 	 Scan: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0008\sample304_0008.h5
# 	 has 63 rows & 400 columns
# 	 Same number of columns in each scan so scanset 304_007_stitch suitable for stitching
# 	 Proceeding to determine crop dimensions for 304_007_stitch
# 	 Scan 1 overlaps with scan 2 by 1 rows.
# 	 Last 1 rows will be dropped from scan 1 in crop list
# Scanset 304_009_stitch:
# 	 Scan: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0009\sample304_0009.h5
# 	 has 384 rows & 400 columns
# 	 Scan: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0010\sample304_0010.h5
# 	 has 6 rows & 400 columns
# 	 Scan: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0011\sample304_0011.h5
# 	 has 20 rows & 400 columns
# 	 Same number of columns in each scan so scanset 304_009_stitch suitable for stitching
# 	 Proceeding to determine crop dimensions for 304_009_stitch
# 	 Scan 1 overlaps with scan 2 by 4 rows.
# 	 Last 4 rows will be dropped from scan 1 in crop list
# 	 Scan 2 overlaps with scan 3 by 6 rows.
# 	 Last 6 rows will be dropped from scan 2 in crop list
#
#
#  Crop dimensions for scansets
# 	 001_002_stitch crop dimensions [16600, 23600]
# 	 001_004_stitch crop dimensions [26000, 14000]
# 	 304_007_stitch crop dimensions [134800, 25200]
# 	 304_009_stitch crop dimensions [152000, 0, 8000]
#
#
#  All scanset crop dimensions identified

# %% [markdown]
# ### Stitch scansets to pre-processed hdf files
# Using the crop dimensions for scans in scansets stored in `crop_dict`, we can now stitch scansets together to the pre-processed datasets.
#
# The following cell first loads the necessary functions for stitching list or array hdf datasets, and the metafunction `stitch_hdf_array_or_list_dset` used by `scanset_reduced_hdf` to produce the new reshaped and reduced datasets.
#
# Reduced stitched scans are output to the `data/processed/xrf/1_reduced_reshaped_hdfs` directory and identified with the `_stitch` suffix.

# %%
#%% This function return a stitched list dataset for specified list datsets in 
#   an hdf5. It requires 1) a list of hdf files containing the specified 
#   dataset, 2) a list of lengths to crop each dataset and 3) the dataset name
def stitch_hdf_list_dset(hdf_list, crop_dims, dset): # (list, list, 'string')
    data = []
    for number, scan in enumerate(hdf_list):
        with h5py.File(scan, 'r') as hdf:
            data_add = hdf[f'{dset}'][:]
            data_add = data_add[:crop_dims[number]]
            data.extend(data_add)
    return data

def stitch_hdf_array_dset(hdf_list, crop_dims, dset): 
    for number, scan in enumerate(hdf_list):
        if number == 0:
            with h5py.File(scan, 'r') as hdf:
                data = hdf[f'{dset}'][:]
                data = data[:crop_dims[number]]
        else:    
            with h5py.File(scan, 'r') as hdf:
                data_add = hdf[f'{dset}'][:]
                data_add = data_add[:crop_dims[number]]
                data = np.concatenate((data, data_add), axis=0)
    return data


#%% This function identifies if the dataset to stitch is a list or an array.
#   It then selects the appropriate function to stitch the dataset type
def stitch_hdf_array_or_list_dset(hdf_list, crop_dims, dset):
    print(hdf_list[0])
    with h5py.File(hdf_list[0], 'r') as hdf_initialise:
        shape = hdf_initialise[f'{dset}'].shape
        shape = (0, shape[-1])
    if len(shape) == 1:
        print('list data')
        data = stitch_hdf_list_dset(hdf_list, crop_dims, dset)
    else:
        print('array data')
        data = stitch_hdf_array_dset(hdf_list, crop_dims, dset)        
    return data
   
def scanset_reduced_hdf(scanset, datasets):
    """
    This function creates a new hdf file for acqusitions comprising 
    multiple scans that need stitching.
    """
    hdf_list = scannames_to_filepaths(scansets[scanset])
        
    print('Scans to stitch:')
    for scan in hdf_list:
        print('\t', scan)
    crop_dims = crop_dict[scanset]
    print('Crop dimensions:', crop_dims)
    
    hdf_new_name = base_dir / out_dir / f'{scanset}.h5'
    print(hdf_new_name)
    
    with h5py.File(hdf_new_name, 'w') as hdf_new:     
        for dset in datasets:
            print(f'\t Adding {scanset} {dset} dataset to new hdf file')
            hdf_datasets[dset] = stitch_hdf_array_or_list_dset(hdf_list = hdf_list,
                                                               crop_dims = crop_dims, 
                                                               dset = dset)
            dset_name = dset.rpartition('/')[-1]
                
            hdf_new.create_dataset(dset_name, data=hdf_datasets[dset], compression='gzip')
        
    print(f'\t Preprocessed hdf file for scanset {scanset} output to: \n\t {hdf_new_name}')
    
    
# Stitch scansets together and output the new hdf files
for scanset in scansets:
    print(f'\n Stitching scanset:', scanset)
    scanset_reduced_hdf(scanset = scanset, datasets = hdf_datasets)
    
    config_file = df_scansets.loc[df_scansets['scanset'] == scanset, 'config_file'].iloc[0]
    step_um = df_scansets.loc[df_scansets['scanset'] == scanset, 'step_um'].iloc[0]
    dual_detector = df_scansets.loc[df_scansets['scanset'] == scanset, 'dual_detector'].iloc[0]
    det_type = df_scansets.loc[df_scansets['scanset'] == scanset, 'detector'].iloc[0]
   
    df_preprocessed_files = df_preprocessed_files.append({'config_file':config_file, 
                                                          'hdf_file':scanset, 
                                                          'step_um':step_um,
                                                          'dual_detector':dual_detector,
                                                          'detector':det_type
                                                         }, ignore_index=True)
    
print('\n All scansets finished stitching')
# Out:
#  Stitching scanset: 001_002_stitch
# Scans to stitch:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0002\sample001_0002.h5
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0002cont\sample001_0002cont.h5
# Crop dimensions: [16600, 23600]
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\001_002_stitch.h5
# 	 Adding 001_002_stitch 1.1/measurement/hrz dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0002\sample001_0002.h5
# array data
# 	 Adding 001_002_stitch 1.1/measurement/hry dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0002\sample001_0002.h5
# array data
# 	 Adding 001_002_stitch 1.1/measurement/fpico3 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0002\sample001_0002.h5
# array data
# 	 Adding 001_002_stitch 1.1/measurement/falconx_det0 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0002\sample001_0002.h5
# array data
# 	 Adding 001_002_stitch 1.1/measurement/fluodet_det0 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0002\sample001_0002.h5
# array data
# 	 Preprocessed hdf file for scanset 001_002_stitch output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\001_002_stitch.h5
#
#  Stitching scanset: 001_004_stitch
# Scans to stitch:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0004\sample001_0004.h5
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0005\sample001_0005.h5
# Crop dimensions: [26000, 14000]
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\001_004_stitch.h5
# 	 Adding 001_004_stitch 1.1/measurement/hrz dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0004\sample001_0004.h5
# array data
# 	 Adding 001_004_stitch 1.1/measurement/hry dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0004\sample001_0004.h5
# array data
# 	 Adding 001_004_stitch 1.1/measurement/fpico3 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0004\sample001_0004.h5
# array data
# 	 Adding 001_004_stitch 1.1/measurement/falconx_det0 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0004\sample001_0004.h5
# array data
# 	 Adding 001_004_stitch 1.1/measurement/fluodet_det0 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0004\sample001_0004.h5
# array data
# 	 Preprocessed hdf file for scanset 001_004_stitch output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\001_004_stitch.h5
#
#  Stitching scanset: 304_007_stitch
# Scans to stitch:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0007\sample304_0007.h5
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0008\sample304_0008.h5
# Crop dimensions: [134800, 25200]
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\304_007_stitch.h5
# 	 Adding 304_007_stitch 1.1/measurement/hrz dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0007\sample304_0007.h5
# array data
# 	 Adding 304_007_stitch 1.1/measurement/hry dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0007\sample304_0007.h5
# array data
# 	 Adding 304_007_stitch 1.1/measurement/fpico3 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0007\sample304_0007.h5
# array data
# 	 Adding 304_007_stitch 1.1/measurement/falconx_det0 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0007\sample304_0007.h5
# array data
# 	 Adding 304_007_stitch 1.1/measurement/fluodet_det0 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0007\sample304_0007.h5
# array data
# 	 Preprocessed hdf file for scanset 304_007_stitch output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\304_007_stitch.h5
#
#  Stitching scanset: 304_009_stitch
# Scans to stitch:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0009\sample304_0009.h5
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0010\sample304_0010.h5
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0011\sample304_0011.h5
# Crop dimensions: [152000, 0, 8000]
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\304_009_stitch.h5
# 	 Adding 304_009_stitch 1.1/measurement/hrz dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0009\sample304_0009.h5
# array data
# 	 Adding 304_009_stitch 1.1/measurement/hry dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0009\sample304_0009.h5
# array data
# 	 Adding 304_009_stitch 1.1/measurement/fpico3 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0009\sample304_0009.h5
# array data
# 	 Adding 304_009_stitch 1.1/measurement/falconx_det0 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0009\sample304_0009.h5
# array data
# 	 Adding 304_009_stitch 1.1/measurement/fluodet_det0 dataset to new hdf file
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0009\sample304_0009.h5
# array data
# 	 Preprocessed hdf file for scanset 304_009_stitch output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\304_009_stitch.h5
#
#  All scansets finished stitching

# %% [markdown]
# ### Reduce complete scans to pre-processed hdf files
# For complete scans that do not need to be stitched, the following cell first loads the metafunction `scan_reduced_hdf` to produce the reduced pre-processed dataset.
#
# Pre-processed datasets are output to the `data/processed/xrf/1_reduced_reshaped_hdfs` directory

# %%
def scan_reduced_hdf(scan, datasets):
    """
    This function creates a new hdf file for acqusitions comprising a single scan.
    """
    hdf_filepath = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'hdf_full_fpaths'].iloc[0]
       
    hdf_new_name = base_dir / out_dir / f'{scan}.h5'
    with h5py.File(hdf_new_name, 'w') as hdf_new:
        for dset in datasets:
            print(f'\t Adding {scan} {dset} dataset to new hdf file')
            hdf_datasets[dset] = hdf_dataset(hdf_filepath = hdf_filepath, dataset = dset)                                         
            dset_name = dset.rpartition('/')[-1]
            hdf_new.create_dataset(dset_name, data=hdf_datasets[dset], compression='gzip')       
    print(f'\t Preprocessed hdf file for scan {scan} output to: \n\t {hdf_new_name}')
    
    
def scan_reduced_hdf_large(scan, datasets):
    """
    This function creates a new hdf file for acqusitions comprising a single scan.
    """
    hdf_filepath = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'hdf_full_fpaths'].iloc[0]
    print(hdf_filepath)
       
    hdf_new_name = base_dir / out_dir / f'{scan}.h5'
    print(hdf_new_name)
    
    datasets = list(hdf_datasets.keys())
        
    with h5py.File(hdf_filepath,'r') as f_src:
        with h5py.File(hdf_new_name,'w') as f_dest:

            for dset in datasets:
                print("dataset", dset)

                # Check dataset exists
                e = dset in f_src

                # Copy existing datasets
                if e == True:
                    print (dset, "exists")
                    new_node = dset.split('/')[-1]
                    f_src.copy(f_src[dset],f_dest, new_node) # copy to new hdf                
                else:
                    pass

    print(f'\t Preprocessed hdf file for scan {scan} output to: \n\t {hdf_new_name}')    
    
for scan in complete_scans:
    print('\n Preprocessing scan:', scan)
    scan_reduced_hdf_large(scan = scan, datasets=hdf_datasets)
                
    config_file = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'config_file'].iloc[0]
    step_um = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'step_um'].iloc[0]
    dual_detector = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'dual_detector'].iloc[0]
    det_type = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'detector'].iloc[0]

    df_preprocessed_files = df_preprocessed_files.append({'config_file':config_file, 
                                                          'hdf_file':scan, 
                                                          'step_um':step_um,
                                                          'dual_detector':dual_detector,
                                                          'detector':det_type
                                                         }, ignore_index=True)
       
print('\n All scans finished reducing')
    
    
    
# for scan in complete_scans:
#     print('\n Preprocessing scan:', scan)
#     scan_reduced_hdf(scan = scan, datasets=hdf_datasets)
                
#     config_file = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'config_file'].iloc[0]
#     step_um = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'step_um'].iloc[0]
#     dual_detector = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'dual_detector'].iloc[0]
#     det_type = df_complete_scans.loc[df_complete_scans['hdf_filename'] == scan, 'detector'].iloc[0]

#     df_preprocessed_files = df_preprocessed_files.append({'config_file':config_file, 
#                                                           'hdf_file':scan, 
#                                                           'step_um':step_um,
#                                                           'dual_detector':dual_detector,
#                                                           'detector':det_type
#                                                          }, ignore_index=True)
       
# print('\n All scans finished reducing')
# Out:
#  Preprocessing scan: sample191_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample191\sample191_0001\sample191_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample191_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample191_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample191_0001.h5
#
#  Preprocessing scan: mylar_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\mylar\mylar_0001\mylar_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\mylar_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan mylar_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\mylar_0001.h5
#
#  Preprocessing scan: sample107_t_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample107_t\sample107_t_0001\sample107_t_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample107_t_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_0001.h5
#
#  Preprocessing scan: sample107_b_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample107_b\sample107_b_0001\sample107_b_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_b_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample107_b_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_b_0001.h5
#
#  Preprocessing scan: sample105_t_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample105_t\sample105_t_0001\sample105_t_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample105_t_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_0001.h5
#
#  Preprocessing scan: sample105_b_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample105_b\sample105_b_0001\sample105_b_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_b_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample105_b_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_b_0001.h5
#
#  Preprocessing scan: sample103_t_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample103_t\sample103_t_0001\sample103_t_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample103_t_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_0001.h5
#
#  Preprocessing scan: sample103_b_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample103_b\sample103_b_0001\sample103_b_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_b_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample103_b_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_b_0001.h5
#
#  Preprocessing scan: sample102_t_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample102_t\sample102_t_0001\sample102_t_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample102_t_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_0001.h5
#
#  Preprocessing scan: sample102_b_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample102_b\sample102_b_0001\sample102_b_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_b_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample102_b_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_b_0001.h5
#
#  Preprocessing scan: axo_thin_film_c00_0005
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\axo_thin_film_c00\axo_thin_film_c00_0005\axo_thin_film_c00_0005.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\axo_thin_film_c00_0005.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan axo_thin_film_c00_0005 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\axo_thin_film_c00_0005.h5
#
#  Preprocessing scan: sample001_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0001\sample001_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample001_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample001_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample001_0001.h5
#
#  Preprocessing scan: sample001_0003
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample001\sample001_0003\sample001_0003.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample001_0003.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample001_0003 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample001_0003.h5
#
#  Preprocessing scan: AXO_thin_film_C00_006_0006
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\axo_thin_film_c00\AXO_thin_film_C00_006_0006\AXO_thin_film_C00_006_0006.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\AXO_thin_film_C00_006_0006.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan AXO_thin_film_C00_006_0006 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\AXO_thin_film_C00_006_0006.h5
#
#  Preprocessing scan: sample304_0013
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0013\sample304_0013.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0013.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample304_0013 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0013.h5
#
#  Preprocessing scan: sample304_0016
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0016\sample304_0016.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0016.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample304_0016 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0016.h5
#
#  Preprocessing scan: sample304_0017
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0017\sample304_0017.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0017.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample304_0017 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0017.h5
#
#  Preprocessing scan: sample304_0018
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0018\sample304_0018.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0018.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 1.1/measurement/fluodet_det0 exists
# 	 Preprocessed hdf file for scan sample304_0018 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0018.h5
#
#  Preprocessing scan: AXO_thin_film_3_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\AXO_thin_film_3\AXO_thin_film_3_0001\AXO_thin_film_3_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\AXO_thin_film_3_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan AXO_thin_film_3_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\AXO_thin_film_3_0001.h5
#
#  Preprocessing scan: AXO_thin_film_3_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\AXO_thin_film_3\AXO_thin_film_3_0002\AXO_thin_film_3_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\AXO_thin_film_3_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan AXO_thin_film_3_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\AXO_thin_film_3_0002.h5
#
#  Preprocessing scan: AXO_thin_film_3_0003
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\AXO_thin_film_3\AXO_thin_film_3_0003\AXO_thin_film_3_0003.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\AXO_thin_film_3_0003.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan AXO_thin_film_3_0003 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\AXO_thin_film_3_0003.h5
#
#  Preprocessing scan: sample102_t_3_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample102_t_3\sample102_t_3_0001\sample102_t_3_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample102_t_3_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0001.h5
#
#  Preprocessing scan: sample102_t_3_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample102_t_3\sample102_t_3_0002\sample102_t_3_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample102_t_3_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0002.h5
#
#  Preprocessing scan: sample102_t_3_0003
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample102_t_3\sample102_t_3_0003\sample102_t_3_0003.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0003.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample102_t_3_0003 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0003.h5
#
#  Preprocessing scan: sample102_t_3_0004
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample102_t_3\sample102_t_3_0004\sample102_t_3_0004.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0004.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample102_t_3_0004 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0004.h5
#
#  Preprocessing scan: sample102_t_3_0005
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample102_t_3\sample102_t_3_0005\sample102_t_3_0005.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0005.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample102_t_3_0005 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0005.h5
#
#  Preprocessing scan: sample102_t_3_0006
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample102_t_3\sample102_t_3_0006\sample102_t_3_0006.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0006.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample102_t_3_0006 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample102_t_3_0006.h5
#
#  Preprocessing scan: sample103_t_3_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample103_t_3\sample103_t_3_0001\sample103_t_3_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample103_t_3_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0001.h5
#
#  Preprocessing scan: sample103_t_3_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample103_t_3\sample103_t_3_0002\sample103_t_3_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample103_t_3_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0002.h5
#
#  Preprocessing scan: sample103_t_3_0003
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample103_t_3\sample103_t_3_0003\sample103_t_3_0003.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0003.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample103_t_3_0003 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0003.h5
#
#  Preprocessing scan: sample103_t_3_0004
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample103_t_3\sample103_t_3_0004\sample103_t_3_0004.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0004.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample103_t_3_0004 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0004.h5
#
#  Preprocessing scan: sample103_t_3_0005
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample103_t_3\sample103_t_3_0005\sample103_t_3_0005.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0005.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample103_t_3_0005 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0005.h5
#
#  Preprocessing scan: sample103_t_3_0006
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample103_t_3\sample103_t_3_0006\sample103_t_3_0006.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0006.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample103_t_3_0006 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample103_t_3_0006.h5
#
#  Preprocessing scan: sample105_t_3_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample105_t_3\sample105_t_3_0001\sample105_t_3_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample105_t_3_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0001.h5
#
#  Preprocessing scan: sample105_t_3_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample105_t_3\sample105_t_3_0002\sample105_t_3_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample105_t_3_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0002.h5
#
#  Preprocessing scan: sample105_t_3_0003
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample105_t_3\sample105_t_3_0003\sample105_t_3_0003.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0003.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample105_t_3_0003 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0003.h5
#
#  Preprocessing scan: sample105_t_3_0004
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample105_t_3\sample105_t_3_0004\sample105_t_3_0004.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0004.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample105_t_3_0004 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0004.h5
#
#  Preprocessing scan: sample105_t_3_0005
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample105_t_3\sample105_t_3_0005\sample105_t_3_0005.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0005.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample105_t_3_0005 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0005.h5
#
#  Preprocessing scan: sample105_t_3_0006
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample105_t_3\sample105_t_3_0006\sample105_t_3_0006.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0006.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample105_t_3_0006 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample105_t_3_0006.h5
#
#  Preprocessing scan: sample107_t_3_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample107_t_3\sample107_t_3_0001\sample107_t_3_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample107_t_3_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0001.h5
#
#  Preprocessing scan: sample107_t_3_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample107_t_3\sample107_t_3_0002\sample107_t_3_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample107_t_3_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0002.h5
#
#  Preprocessing scan: sample107_t_3_0003
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample107_t_3\sample107_t_3_0003\sample107_t_3_0003.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0003.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample107_t_3_0003 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0003.h5
#
#  Preprocessing scan: sample107_t_3_0004
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample107_t_3\sample107_t_3_0004\sample107_t_3_0004.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0004.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample107_t_3_0004 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0004.h5
#
#  Preprocessing scan: sample107_t_3_0005
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample107_t_3\sample107_t_3_0005\sample107_t_3_0005.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0005.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample107_t_3_0005 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0005.h5
#
#  Preprocessing scan: sample107_t_3_0006
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample107_t_3\sample107_t_3_0006\sample107_t_3_0006.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0006.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample107_t_3_0006 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_3_0006.h5
#
#  Preprocessing scan: GeCMOS_blank_1000
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GeCMOS_blank\GeCMOS_blank_1000\GeCMOS_blank_1000.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\GeCMOS_blank_1000.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan GeCMOS_blank_1000 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\GeCMOS_blank_1000.h5
#
#  Preprocessing scan: GeCMOS_blank_100
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GeCMOS_blank\GeCMOS_blank_100\GeCMOS_blank_100.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\GeCMOS_blank_100.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan GeCMOS_blank_100 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\GeCMOS_blank_100.h5
#
#  Preprocessing scan: GeCMOS_blank_10
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GeCMOS_blank\GeCMOS_blank_10\GeCMOS_blank_10.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\GeCMOS_blank_10.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan GeCMOS_blank_10 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\GeCMOS_blank_10.h5
#
#  Preprocessing scan: sample304_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0001\sample304_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample304_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0001.h5
#
#  Preprocessing scan: sample304_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304\sample304_0002\sample304_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample304_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0002.h5
#
#  Preprocessing scan: sample304_b_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304_b\sample304_b_0001\sample304_b_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_b_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample304_b_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_b_0001.h5
#
#  Preprocessing scan: sample304_b_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304_b\sample304_b_0002\sample304_b_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_b_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample304_b_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_b_0002.h5
#
#  Preprocessing scan: sample304_b_0003
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304_b\sample304_b_0003\sample304_b_0003.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_b_0003.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample304_b_0003 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_b_0003.h5
#
#  Preprocessing scan: sample304_b_0004
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\sample304_b\sample304_b_0004\sample304_b_0004.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_b_0004.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan sample304_b_0004 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_b_0004.h5
#
#  Preprocessing scan: st_cp_column2_aglfxd_2_10Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\CellPellet_stIMC\A431\st_cp_column2_aglfxd_2_10Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column2_aglfxd_2_10Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan st_cp_column2_aglfxd_2_10Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column2_aglfxd_2_10Hz_0001.h5
#
#  Preprocessing scan: st_cp_column2_aglfxd_50Hz_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\CellPellet_stIMC\A431\st_cp_column2_aglfxd_50Hz_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column2_aglfxd_50Hz_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan st_cp_column2_aglfxd_50Hz_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column2_aglfxd_50Hz_0002.h5
#
#  Preprocessing scan: st_cp_column2_angle_250Hz_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\CellPellet_stIMC\A431\st_cp_column2_angle_250Hz_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column2_angle_250Hz_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan st_cp_column2_angle_250Hz_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column2_angle_250Hz_0002.h5
#
#  Preprocessing scan: st_cp_1_column1_10Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\CellPellet_stIMC\MCF10a\st_cp_1_column1_10Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_1_column1_10Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan st_cp_1_column1_10Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_1_column1_10Hz_0001.h5
#
#  Preprocessing scan: st_cp_column1_50Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\CellPellet_stIMC\MCF10a\st_cp_column1_50Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column1_50Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan st_cp_column1_50Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column1_50Hz_0001.h5
#
#  Preprocessing scan: st_cp_column1_250Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\CellPellet_stIMC\MCF10a\st_cp_column1_250Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column1_250Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan st_cp_column1_250Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column1_250Hz_0001.h5
#
#  Preprocessing scan: st_cp_1_column1_10Hz_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\CellPellet_stIMC\SKBR3\st_cp_1_column1_10Hz_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_1_column1_10Hz_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan st_cp_1_column1_10Hz_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_1_column1_10Hz_0002.h5
#
#  Preprocessing scan: st_cp_column1_50Hz_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\CellPellet_stIMC\SKBR3\st_cp_column1_50Hz_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column1_50Hz_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan st_cp_column1_50Hz_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column1_50Hz_0002.h5
#
#  Preprocessing scan: st_cp_column1_250Hz_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\CellPellet_stIMC\SKBR3\st_cp_column1_250Hz_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\st_cp_column1_250Hz_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan st_cp_column1_250Hz_0002 output to:
# ...
#
#  Preprocessing scan: g194_1000Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\10_mylaronly\g194_1000Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\g194_1000Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan g194_1000Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\g194_1000Hz_0001.h5
#
#  Preprocessing scan: blank_tower_10Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\11_toweronly\blank_tower_10Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_10Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_tower_10Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_10Hz_0001.h5
#
#  Preprocessing scan: blank_tower_50Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\11_toweronly\blank_tower_50Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_50Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_tower_50Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_50Hz_0001.h5
#
#  Preprocessing scan: blank_tower_250Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\11_toweronly\blank_tower_250Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_250Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_tower_250Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_250Hz_0001.h5
#
#  Preprocessing scan: blank_tower_500Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\11_toweronly\blank_tower_500Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_500Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_tower_500Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_500Hz_0001.h5
#
#  Preprocessing scan: blank_tower_800Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\11_toweronly\blank_tower_800Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_800Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_tower_800Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_800Hz_0001.h5
#
#  Preprocessing scan: blank_tower_1000Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\11_toweronly\blank_tower_1000Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_1000Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_tower_1000Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_tower_1000Hz_0001.h5
#
#  Preprocessing scan: blank_env_10Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\12_nothing\blank_env_10Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_10Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_env_10Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_10Hz_0001.h5
#
#  Preprocessing scan: blank_env_50Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\12_nothing\blank_env_50Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_50Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_env_50Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_50Hz_0001.h5
#
#  Preprocessing scan: blank_env_250Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\12_nothing\blank_env_250Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_250Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_env_250Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_250Hz_0001.h5
#
#  Preprocessing scan: blank_env_500Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\12_nothing\blank_env_500Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_500Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_env_500Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_500Hz_0001.h5
#
#  Preprocessing scan: blank_env_800Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\12_nothing\blank_env_800Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_800Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_env_800Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_800Hz_0001.h5
#
#  Preprocessing scan: blank_env_1000Hz_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\GelatinStandards\12_nothing\blank_env_1000Hz_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_1000Hz_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan blank_env_1000Hz_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\blank_env_1000Hz_0001.h5
#
#  Preprocessing scan: appendix_a1_overview_solid_0002
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\appendix_a1_overview_solid\appendix_a1_overview_solid_0002\appendix_a1_overview_solid_0002.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\appendix_a1_overview_solid_0002.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan appendix_a1_overview_solid_0002 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\appendix_a1_overview_solid_0002.h5
#
#  Preprocessing scan: appendix_a1_ROI_solid_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\appendix_a1_ROI_solid\appendix_a1_ROI_solid_0001\appendix_a1_ROI_solid_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\appendix_a1_ROI_solid_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan appendix_a1_ROI_solid_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\appendix_a1_ROI_solid_0001.h5
#
#  Preprocessing scan: tonsil_t1_overview_solid_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\tonsil_t1_overview_solid\tonsil_t1_overview_solid_0001\tonsil_t1_overview_solid_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\tonsil_t1_overview_solid_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan tonsil_t1_overview_solid_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\tonsil_t1_overview_solid_0001.h5
#
#  Preprocessing scan: tonsil_t1_ROI_solid_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\tonsil_t1_ROI_solid\tonsil_t1_ROI_solid_0001\tonsil_t1_ROI_solid_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\tonsil_t1_ROI_solid_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan tonsil_t1_ROI_solid_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\tonsil_t1_ROI_solid_0001.h5
#
#  Preprocessing scan: breast_cancer_b2_solid_overview_0corrected_0003
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\breast_cancer_b2_solid_overview_0corrected\breast_cancer_b2_solid_overview_0corrected_0003\breast_cancer_b2_solid_overview_0corrected_0003.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\breast_cancer_b2_solid_overview_0corrected_0003.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan breast_cancer_b2_solid_overview_0corrected_0003 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\breast_cancer_b2_solid_overview_0corrected_0003.h5
#
#  Preprocessing scan: breast_cancer_b2_ROI_solid_ROI_0001
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\breast_cancer_b2_ROI_solid_ROI\breast_cancer_b2_ROI_solid_ROI_0001\breast_cancer_b2_ROI_solid_ROI_0001.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\breast_cancer_b2_ROI_solid_ROI_0001.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan breast_cancer_b2_ROI_solid_ROI_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\breast_cancer_b2_ROI_solid_ROI_0001.h5
#
#  Preprocessing scan: breast_cancer_b2_ROI_solid_0003
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\raw\xrf\scans\breast_cancer_b2_ROI_solid\breast_cancer_b2_ROI_solid_0003\breast_cancer_b2_ROI_solid_0003.h5
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\breast_cancer_b2_ROI_solid_0003.h5
# dataset 1.1/measurement/hrz
# 1.1/measurement/hrz exists
# dataset 1.1/measurement/hry
# 1.1/measurement/hry exists
# dataset 1.1/measurement/fpico3
# 1.1/measurement/fpico3 exists
# dataset 1.1/measurement/falconx_det0
# 1.1/measurement/falconx_det0 exists
# dataset 1.1/measurement/fluodet_det0
# 	 Preprocessed hdf file for scan breast_cancer_b2_ROI_solid_0003 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\breast_cancer_b2_ROI_solid_0003.h5
#
#  All scans finished reducing

# %% [markdown]
# ### Scans with different dataset structure
# During acquisition, some raw .hdf scans end up storing datasets in 2.1/measurements hdf node rather than 1.1/measurements. For these scans (which can be identified by small file size if reduced in the prior step), hdf reduction needs to be pointed to this different dataset structure.
#
# For scans listed in `scans_in_2pt1`, reduced .hdfs are rederived in the following cell by defining this structure.

# %%
scans_in_2pt1 = ['sample107_t_0001', 'sample304_0017', 'sample304_b_0004']

# Switch dataset directory from 1.1 to 2.1
hdf_datasets_2 = list(hdf_datasets)
hdf_datasets_2 = [dset.replace('1.1', '2.1') for dset in hdf_datasets_2]
hdf_datasets_2 = dict.fromkeys(hdf_datasets_2)

for scan in scans_in_2pt1:
    print('\n Preprocessing scan:', scan)
    scan_reduced_hdf(scan = scan, datasets=hdf_datasets_2)
    
print('\n Irregular complete scans processed to pre-processed directory')
# Out:
#  Preprocessing scan: sample107_t_0001
# 	 Adding sample107_t_0001 2.1/measurement/hrz dataset to new hdf file
# 	 Adding sample107_t_0001 2.1/measurement/hry dataset to new hdf file
# 	 Adding sample107_t_0001 2.1/measurement/fpico3 dataset to new hdf file
# 	 !!! 2.1/measurement/fpico3 does not exist, could not retrieve dataset
# 	 Adding sample107_t_0001 2.1/measurement/falconx_det0 dataset to new hdf file
# 	 Adding sample107_t_0001 2.1/measurement/fluodet_det0 dataset to new hdf file
# 	 Preprocessed hdf file for scan sample107_t_0001 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample107_t_0001.h5
#
#  Preprocessing scan: sample304_0017
# 	 Adding sample304_0017 2.1/measurement/hrz dataset to new hdf file
# 	 Adding sample304_0017 2.1/measurement/hry dataset to new hdf file
# 	 Adding sample304_0017 2.1/measurement/fpico3 dataset to new hdf file
# 	 Adding sample304_0017 2.1/measurement/falconx_det0 dataset to new hdf file
# 	 Adding sample304_0017 2.1/measurement/fluodet_det0 dataset to new hdf file
# 	 Preprocessed hdf file for scan sample304_0017 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_0017.h5
#
#  Preprocessing scan: sample304_b_0004
# 	 Adding sample304_b_0004 2.1/measurement/hrz dataset to new hdf file
# 	 Adding sample304_b_0004 2.1/measurement/hry dataset to new hdf file
# 	 Adding sample304_b_0004 2.1/measurement/fpico3 dataset to new hdf file
# 	 Adding sample304_b_0004 2.1/measurement/falconx_det0 dataset to new hdf file
# 	 Adding sample304_b_0004 2.1/measurement/fluodet_det0 dataset to new hdf file
# 	 !!! 2.1/measurement/fluodet_det0 does not exist, could not retrieve dataset
# 	 Preprocessed hdf file for scan sample304_b_0004 output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\1_reduced_reshaped_hdfs\sample304_b_0004.h5
#
#  Irregular complete scans processed to pre-processed directory

# %% [markdown]
# Export csv tracking preprocessed files alongside infomration key to deconvolution and later processing.

# %%
df_preprocessed_files.to_csv((out_dir / 'preprocessed_hdf_config_files.csv'), index=False)

# %% [markdown]
# Generate fpico mask to normalise later plots according to X-ray flux. These will be added to the output hdf reduced, reshaped .h5 files.

# %%
# hdf_img_fpaths = [i for i in out_dir.glob('*.h5')]
hdf_img_fpaths = [list(out_dir.glob(f'{i}.h5'))[0] for i in df_preprocessed_files['hdf_file']]

def hdf_fpico_mask(hdf_img_fpath):
    print(hdf_img_fpath.stem)
    with h5py.File(hdf_img_fpath, 'r+') as hdf:    
        z = list(hdf['hrz'][:])
        y = list(hdf['hry'][:])
        rows = len(np.unique(z))
        cols = int(len(y)/rows)
        
        try:     
            fpico3 = hdf['fpico3'][:]

        except KeyError:
            print(f'\t !!! fpico3 does not exist, could not retrieve dataset')
            fpico3 = np.ones((1, rows*cols))  

        if len(fpico3) > 10:
            fpico_mask = fpico3.reshape((rows, cols))

            if 'fpico_mask' in hdf:
                hdf['fpico_mask'][...] = fpico_mask
            else:
                hdf.create_dataset(name = 'fpico_mask', data = fpico_mask)   
        else:
            fpico_mask = np.ones((rows,cols))
                    
        return fpico_mask
    
for hdf_img_fpath in hdf_img_fpaths[:]:
    fpico_mask = hdf_fpico_mask(hdf_img_fpath)
# Out:
# 001_002_stitch
# 001_004_stitch
# 304_007_stitch
# 304_009_stitch
# sample191_0001
# 	 !!! fpico3 does not exist, could not retrieve dataset
# mylar_0001
# 	 !!! fpico3 does not exist, could not retrieve dataset
# sample107_t_0001
# sample107_b_0001
# 	 !!! fpico3 does not exist, could not retrieve dataset
# sample105_t_0001
# sample105_b_0001
# sample103_t_0001
# sample103_b_0001
# sample102_t_0001
# sample102_b_0001
# axo_thin_film_c00_0005
# sample001_0001
# sample001_0003
# AXO_thin_film_C00_006_0006
# 	 !!! fpico3 does not exist, could not retrieve dataset
# sample304_0013
# sample304_0016
# sample304_0017
# sample304_0018
# AXO_thin_film_3_0001
# AXO_thin_film_3_0002
# AXO_thin_film_3_0003
# sample102_t_3_0001
# sample102_t_3_0002
# sample102_t_3_0003
# sample102_t_3_0004
# sample102_t_3_0005
# sample102_t_3_0006
# sample103_t_3_0001
# sample103_t_3_0002
# sample103_t_3_0003
# sample103_t_3_0004
# sample103_t_3_0005
# sample103_t_3_0006
# sample105_t_3_0001
# sample105_t_3_0002
# sample105_t_3_0003
# sample105_t_3_0004
# sample105_t_3_0005
# sample105_t_3_0006
# sample107_t_3_0001
# sample107_t_3_0002
# sample107_t_3_0003
# sample107_t_3_0004
# sample107_t_3_0005
# sample107_t_3_0006
# GeCMOS_blank_1000
# GeCMOS_blank_100
# GeCMOS_blank_10
# sample304_0001
# sample304_0002
# sample304_b_0001
# sample304_b_0002
# sample304_b_0003
# sample304_b_0004
# st_cp_column2_aglfxd_2_10Hz_0001
# st_cp_column2_aglfxd_50Hz_0002
# st_cp_column2_angle_250Hz_0002
# st_cp_1_column1_10Hz_0001
# st_cp_column1_50Hz_0001
# st_cp_column1_250Hz_0001
# st_cp_1_column1_10Hz_0002
# st_cp_column1_50Hz_0002
# st_cp_column1_250Hz_0002
# st_cp_column2_aglfxd_10Hz_0001
# st_cp_column2_aglfxd_50Hz_0001
# st_cp_column2_angle_250Hz_0001
# bl_cp_column2_10Hz_0002
# bl_cp_column2_50Hz_0002
# bl_cp_column2_250Hz_0004
# bl_cp_column1_10Hz_0001
# bl_cp_column1_50Hz_0001
# bl_cp_column1_250Hz_0001
# bl_cp_skbr3re_10Hz_0001
# bl_cp_skbr3re_50Hz_0001
# bl_cp_skbr3re_250Hz_0001
# bl_cp_column2_10Hz_0001
# bl_cp_column2_50Hz_0001
# bl_cp_column2_250Hz_0003
# sp_cp_column2_10Hz_0002
# sp_cp_column2_50Hz_0002
# sp_cp_column2_250Hz_0002
# sp_cp_a431real_500Hz_0001
# sp_cp_a431real_800Hz_0001
# sp_cp_a431real_1000Hz_0001
# sp_cp_a431real_1500Hz_0001
# sp_cp_column1_10Hz_0001
# sp_cp_column1_50Hz_0001
# sp_cp_column1_250Hz_0001
# sp_cp_mcf10a_500Hz_0001
# sp_cp_mcf10a_800Hz_0001
# sp_cp_mcf10a_1000Hz_0001
# sp_cp_mcf10a_1500Hz_0001
# sp_cp_column1_10Hz_0002
# sp_cp_column1_50Hz_0002
# sp_cp_column1_250Hz_0002
# sp_cp_skbr3_500Hz_0001
# sp_tt_skbr3_800Hz_0001
# sp_tt_skbr3_1000Hz_0001
# sp_cp_skbr3_1500Hz_0002
# sp_cp_column2_10Hz_0001
# sp_cp_column2_50Hz_0001
# sp_cp_column2_250Hz_0001
# sp_cp_a431_500Hz_0001
# sp_cp_a431_800Hz_0001
# sp_cp_a431_1000Hz_0001
# sp_cp_zr751_1500Hz_0002
# st_tt_h2_inset_10Hz_0002
# st_tt_h2lb2_50Hz_0001
# st_tt_h2lb2_250Hz_0001
# st_tt_hl4_inset_10Hz_0001
# st_tt_hl4_inset_50Hz_0002
# st_tt_hl4_250Hz_0001
# st_tt_lb2_inset_10Hz_0001
# st_tt_h2lb2_50Hz_0002
# st_tt_h2lb2_250Hz_0002
# st_tt_lbh4_inset_10Hz_0001
# st_tt_lbh4_inset_50Hz_0001
# st_tt_lbh4_250Hz_0001
# bl_tt_h2_inset_10Hz_0002
# bl_tt_h2_50Hz_0001
# bl_tt_h2_250Hz_0001
# bl_tt_lb2_inset1_10Hz_0001
# bl_tt_lb2_50Hz_0001
# bl_tt_lb2_250Hz_0001
# bl_tt_lbh4_inset_10Hz_0001
# bl_tt_lbh4_50Hz_0001
# bl_tt_lbh4_250Hz_0001
# sp_tt_h2_inset_10Hz_0001
# sp_tt_h2_inset_50Hz_0001
# sp_tt_h2_250Hz_0001
# sp_tt_h2_500Hz_0001
# sp_tt_lb2h2_800Hz_0002
# sp_tt_hl4_inset_50Hz_0001
# sp_tt_hl4_250Hz_0001
# sp_tt_lb2_inset_50Hz_0001
# sp_tt_lb2_250Hz_0001
# sp_tt_lb2_500Hz_0001
# sp_tt_lb2h2_800Hz_0001
# sp_tt_lbh4_inset_50Hz_0001
# sp_tt_lbh4_250Hz_0001
# sp_tt_lbh4_500Hz_0001
# sp_tt_lbh4_800Hz_0001
# sp_tt_h2_step25_800Hz_0001
# sp_tt_lbh4_step25_50Hz_0001
# sp_tt_lbh4_step25_250Hz_0001
# sp_tt_lbh4_step25_500Hz_0001
# sp_tt_lbh4_step25_800Hz_0001
# g102t_10Hz_0004
# g102t_50Hz_0004
# g102t_250Hz_0004
# g102t_500Hz_0001
# g102t_800Hz_0001
# g102t_1000Hz_0001
# g102b_10Hz_0001
# g102b_50Hz_0001
# g102b_250Hz_0002
# g102b_500Hz_0001
# g102b_800Hz_0001
# g102b_1000Hz_0001
# g104t_10Hz_0001
# g104t_50Hz_0001
# g104t_250Hz_0001
# g104t_500Hz_0001
# g104t_800Hz_0001
# g104t_1000Hz_0001
# g104b_10Hz_0001
# g104b_50Hz_0001
# g104b_250Hz_0001
# g104b_500Hz_0001
# g104b_800Hz_0001
# g104b_1000Hz_0001
# g106t_10Hz_0001
# g106t_50Hz_0002
# g106t_250Hz_0001
# g106t_500Hz_0001
# g106t_800Hz_0001
# g106t_1000Hz_0001
# g106b_10Hz_0001
# g106b_50Hz_0001
# g106b_250Hz_0001
# g106b_500Hz_0001
# g106b_800Hz_0001
# g106b_1000Hz_0001
# g108t_10Hz_0001
# g108t_50Hz_0001
# g108t_250Hz_0001
# g108t_500Hz_0001
# g108t_800Hz_0001
# g108t_1000Hz_0001
# g108b_10Hz_0001
# g108b_50Hz_0001
# g108b_250Hz_0001
# g108b_500Hz_0001
# g108b_800Hz_0001
# g108b_1000Hz_0001
# g192_10Hz_0001
# g192_50Hz_0001
# g192_250Hz_0001
# g192_500Hz_0001
# g192_800Hz_0002
# g192_1000Hz_0001
# g194_10Hz_0001
# g194_50Hz_0001
# g194_250Hz_0001
# g194_500Hz_0001
# g194_800Hz_0001
# g194_1000Hz_0001
# blank_tower_10Hz_0001
# blank_tower_50Hz_0001
# blank_tower_250Hz_0001
# blank_tower_500Hz_0001
# blank_tower_800Hz_0001
# blank_tower_1000Hz_0001
# blank_env_10Hz_0001
# blank_env_50Hz_0001
# blank_env_250Hz_0001
# blank_env_500Hz_0001
# blank_env_800Hz_0001
# blank_env_1000Hz_0001
# appendix_a1_overview_solid_0002
# appendix_a1_ROI_solid_0001
# tonsil_t1_overview_solid_0001
# tonsil_t1_ROI_solid_0001
# breast_cancer_b2_solid_overview_0corrected_0003
# breast_cancer_b2_ROI_solid_ROI_0001
# breast_cancer_b2_ROI_solid_0003

# %% [markdown]
# Add in scan step size to each preprocessed hdf file

# %%
for hdf_img_fpath in hdf_img_fpaths:
    step = df_preprocessed_files.loc[df_preprocessed_files['hdf_file'] == hdf_img_fpath.stem, 'step_um'].iloc[0]
    
    with h5py.File(hdf_img_fpath, 'r+') as hdf:
        hdf.create_dataset(name = 'step_um', data = step)
