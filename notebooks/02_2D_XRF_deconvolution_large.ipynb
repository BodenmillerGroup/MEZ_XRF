# %% [markdown]
# # 2. 2D XRF deconvolution of pre-processed hdf files
# ## Summary
# This notebook takes the pre-processed .hdf files produced with the `1_reduced_reshaped_xrf_hdf` notebook and deconvolutes to element channel images using the PyMCA package.

# %%
import pathlib
import shutil
import numpy as np
import pandas as pd
import h5py
import cv2
import matplotlib.pyplot as plt

from PyMca5.PyMcaPhysics.xrf.XRFBatchFitOutput import OutputBuffer
from PyMca5.PyMcaPhysics.xrf.FastXRFLinearFit import FastXRFLinearFit

# %%
# Set data directory to work from 
base_dir = "C:/Users/MerrickS/OneDrive/Work/2_UZH/Papers/1_MEZ_XRF"
base_dir = pathlib.Path(base_dir)

# Specify the input directory where hdf files to process are located
hdf_dir = base_dir / 'data' / 'processed' / 'xrf' / '1_reduced_reshaped_hdfs'

# Specify the config directory where config files for deconvolution are located
cfg_dir = base_dir / 'data' / 'raw' / 'xrf' / 'config'

# Make output directory for reshaped hdf files if it does not exist
out_dir = base_dir / 'data' / 'processed' / 'xrf' / '2_deconvoluted_hdfs'
out_dir.mkdir(parents=True, exist_ok=True)
print('\n Deconvoluted hdf files will be output to: \n\t', base_dir, out_dir) 

# Gather filepaths for preprocessed hdfs and config files for XRF fitting
hdf_filepaths = list(hdf_dir.glob('*.h5'))

# Read in scan and scanset metadata
df_hdf_config = pd.read_csv(hdf_dir /'preprocessed_hdf_config_files.csv')
# Out:
#  Deconvoluted hdf files will be output to:
# 	 C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs

# %%
# Make hdf XRF fit config dictionary 
hdf_list = df_hdf_config['hdf_file'].tolist()
config_list = df_hdf_config['config_file'].tolist()
hdf_config_dict = dict(zip(hdf_list, config_list))

# %%
def hdf_dataset(hdf_filepath, dataset): 
    with h5py.File(hdf_filepath, 'r') as hdf:
        node = f"{dataset}"
        try:            
            hdf[node]
            dset = hdf[dataset]
        except KeyError:
            dset = []
            print(f'Could not find hdf dataset for {hdf_filepath}')

        dset = dset[:]
    return dset

def hdf_large_dataset(hdf_filepath, dataset, dims): 
    with h5py.File(hdf_filepath, 'r') as hdf:
        node = f"{dataset}"
        try:            
            hdf[node]
            dset = hdf[dataset]
        except KeyError:
            dset = []
            print(f'Could not find hdf dataset for {hdf_filepath}')

        dset = dset[dims[0]:dims[1],:]
    return dset

def xrf_deconvolute(hdf_file, detector, refit_state=False, weight=0):
    # Check hdf file exists
    input_hdf_fpath = hdf_dir / f'{hdf_file}.h5'
    if input_hdf_fpath.exists() is False:
        print(f'{input_hdf_fpath} does not exist')
        
    # Check detector node exists
    node_exists = False
    with h5py.File(input_hdf_fpath, 'r+') as hdf:  
        node_exists = detector in hdf
        print(f'{detector} node exists: ', node_exists)
        if node_exists == True:
            det_entries = hdf[detector].shape[0]
            print(det_entries)
            if det_entries > 100:
                node_exists = True
            else:
                node_exists = False
                print(detector, 'empty, no fit performed')
    
    if node_exists == True:
        # Check cfg file exists
        config_filepath = cfg_dir / hdf_config_dict[hdf_file]
        if config_filepath.exists() is False:
            print(f'{config_filepath} does not exist')

        # Make output subdir if does not exist
        out_sub_dir = out_dir / 'per_detector_deconvolutions' / hdf_file / detector
        out_sub_dir.mkdir(parents=True, exist_ok=True)

        # Get dataset to deconvolute and reshape to 3D array (2D array of spectra) for PyMCA
        # Establish if need to chunk data
        if det_entries > 2000000:
            z_dim = len(list(set(hdf_dataset(input_hdf_fpath, 'hrz'))))
            y_dim = int(len(list(hdf_dataset(input_hdf_fpath, 'hry')))/z_dim)
            print('large dataset', 'z', z_dim, 'y', y_dim)

            # Find chunk size            
            chunks = 10
            if z_dim % chunks == 0:
                print("Chunks:", chunks)
            else:
                print("Chunk error, can't find equal division of data")

            chunk_size = int(det_entries / chunks)
            chunk_dims = [[i*chunk_size,(i+1)*chunk_size] for i in range(chunks)]
            print(chunk_dims)

        else: 
            z_dim = len(list(set(hdf_dataset(input_hdf_fpath, 'hrz'))))
            y_dim = int(len(list(hdf_dataset(input_hdf_fpath, 'hry')))/z_dim)
            print('small dataset', 'z', z_dim, 'y', y_dim)
            chunks = 0

        # Deconvolution for chunked data
        if chunks != 0:
            for chunk in range(chunks):
                out_sub_sub_dir = out_sub_dir / f'chunk_{chunk}'
                out_sub_sub_dir.mkdir(parents=True, exist_ok=True)
                print("Deconvoluting spectral chunk:", chunk_dims[chunk])                    
                spectra_stack = hdf_large_dataset(input_hdf_fpath, detector, chunk_dims[chunk])
                print("spectra shape", spectra_stack.shape)
                spectra_stack = spectra_stack.reshape(int(z_dim/chunks), y_dim, spectra_stack.shape[-1])         
                print("reshaped spectra shape", spectra_stack.shape)        

                # Pymca fit
                if node_exists == True:
                    pymca_object = FastXRFLinearFit()    

                    print('spectra config file:', config_filepath.name)

                    FastXRFLinearFit.setFitConfigurationFile(pymca_object, str(config_filepath))

                    test_out = OutputBuffer(outputDir=out_sub_sub_dir,
                                            edf=0,
                                            tif=False,
                                            overwrite=True,
                                            outputRoot=hdf_file, 
                                            fileEntry=hdf_file
                                            )

                    FastXRFLinearFit.fitMultipleSpectra(pymca_object, 
                                                        y=spectra_stack, 
                                                        weight=weight, 
                                                        refit=refit_state, 
                                                        concentrations=False,
                                                        outbuffer=test_out)

                    # Extract tifs from hdf channels
                    output_hdf_fpath = list(out_sub_sub_dir.glob('*h5'))[0]
                    with h5py.File(output_hdf_fpath, 'r+') as hdf:
                        node = f"{output_hdf_fpath.stem}/plotselect"

                        image_dir = output_hdf_fpath.parent / "IMAGES"
                        image_dir.mkdir(parents=True, exist_ok=True)
                        for img in hdf[node].keys():
                            subnode = f"{node}/{img}"
                            dset = hdf[subnode][...]
                            outpath = str(image_dir / f'{img}.tiff')
                            cv2.imwrite(outpath, dset)

                    # Carry over the fpico normalisation mask is exists
                    output_hdf_fpath = list(out_sub_sub_dir.glob('*h5'))[0]

                    with h5py.File(input_hdf_fpath, 'r') as hdf:
                        if 'fpico_mask' in hdf:
                            fpico_mask = hdf['fpico_mask'][:]
                        else:
                            fpico_mask = False

                    print('output hdf file:', output_hdf_fpath)

                    if isinstance(fpico_mask, np.ndarray):
                        with h5py.File(output_hdf_fpath, 'r+') as hdf:
                              hdf.create_dataset(name = 'fpico_mask', data = fpico_mask)
                else:
                    pass

        # Deconvolution for non-chunked data
        if chunks == 0:
            spectra_stack = hdf_dataset(input_hdf_fpath, detector)
            print("spectra shape", spectra_stack.shape)
            spectra_stack = spectra_stack.reshape(int(z_dim), y_dim, spectra_stack.shape[-1])         
            print("reshaped spectra shape", spectra_stack.shape)        

            # Pymca fit
            if node_exists == True:
                pymca_object = FastXRFLinearFit()    

                print('spectra config file:', config_filepath.name)

                FastXRFLinearFit.setFitConfigurationFile(pymca_object, str(config_filepath))

                test_out = OutputBuffer(outputDir=out_sub_dir,
                                        edf=0,
                                        tif=True,
                                        overwrite=True,
                                        outputRoot=hdf_file, 
                                        fileEntry=hdf_file
                                        )

                FastXRFLinearFit.fitMultipleSpectra(pymca_object, 
                                                    y=spectra_stack, 
                                                    weight=weight, 
                                                    refit=refit_state, 
                                                    concentrations=False,
                                                    outbuffer=test_out)

                # Carry over the fpico normalisation mask is exists
                output_hdf_fpath = list(out_sub_dir.glob('*h5'))[0]

                with h5py.File(input_hdf_fpath, 'r') as hdf:
                    if 'fpico_mask' in hdf:
                        fpico_mask = hdf['fpico_mask'][:]
                    else:
                        fpico_mask = False

                print('output hdf file:', output_hdf_fpath)

                if isinstance(fpico_mask, np.ndarray):
                    with h5py.File(output_hdf_fpath, 'r+') as hdf:
                          hdf.create_dataset(name = 'fpico_mask', data = fpico_mask)
            else:
                pass
    else:
        pass

# %% [markdown]
# Perform deconvolutions on both detectors (where present).

# %%
for hdf_file in hdf_list:
    print('\n', hdf_file)
    xrf_deconvolute(hdf_file, 'falconx_det0', refit_state=True)
    xrf_deconvolute(hdf_file, 'fluodet_det0', refit_state=True)

print('\n All files processed')
# Out:
#  001_002_stitch
# falconx_det0 node exists:  True
# 40200
# small dataset z 201 y 200
# spectra shape (40200, 4096)
# reshaped spectra shape (201, 200, 4096)
# spectra config file: 21_04_22_SDD_AXO_ls2893_1_002_stitch.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\001_002_stitch\falconx_det0\001_002_stitch.h5
# fluodet_det0 node exists:  True
# 40200
# small dataset z 201 y 200
# spectra shape (40200, 4096)
# reshaped spectra shape (201, 200, 4096)
# spectra config file: 21_04_22_SDD_AXO_ls2893_1_002_stitch.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\001_002_stitch\fluodet_det0\001_002_stitch.h5
#
#  001_004_stitch
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_04_22_SDD_AXO_ls2893_1_004_stitch.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\001_004_stitch\falconx_det0\001_004_stitch.h5
# fluodet_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_04_22_SDD_AXO_ls2893_1_004_stitch.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\001_004_stitch\fluodet_det0\001_004_stitch.h5
#
#  304_007_stitch
# falconx_det0 node exists:  True
# 160000
# small dataset z 400 y 400
# spectra shape (160000, 4096)
# reshaped spectra shape (400, 400, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\304_007_stitch\falconx_det0\304_007_stitch.h5
# fluodet_det0 node exists:  True
# 160000
# small dataset z 400 y 400
# spectra shape (160000, 4096)
# reshaped spectra shape (400, 400, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\304_007_stitch\fluodet_det0\304_007_stitch.h5
#
#  304_009_stitch
# falconx_det0 node exists:  True
# 160000
# small dataset z 400 y 400
# spectra shape (160000, 4096)
# reshaped spectra shape (400, 400, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\304_009_stitch\falconx_det0\304_009_stitch.h5
# fluodet_det0 node exists:  True
# 160000
# small dataset z 400 y 400
# spectra shape (160000, 4096)
# reshaped spectra shape (400, 400, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\304_009_stitch\fluodet_det0\304_009_stitch.h5
#
#  sample191_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample191_0001\falconx_det0\sample191_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample191_0001\fluodet_det0\sample191_0001.h5
#
#  mylar_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\mylar_0001\falconx_det0\mylar_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\mylar_0001\fluodet_det0\mylar_0001.h5
#
#  sample107_t_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_0001\falconx_det0\sample107_t_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_0001\fluodet_det0\sample107_t_0001.h5
#
#  sample107_b_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_b_0001\falconx_det0\sample107_b_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_b_0001\fluodet_det0\sample107_b_0001.h5
#
#  sample105_t_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_0001\falconx_det0\sample105_t_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_0001\fluodet_det0\sample105_t_0001.h5
#
#  sample105_b_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_b_0001\falconx_det0\sample105_b_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_b_0001\fluodet_det0\sample105_b_0001.h5
#
#  sample103_t_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_0001\falconx_det0\sample103_t_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_0001\fluodet_det0\sample103_t_0001.h5
#
#  sample103_b_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_b_0001\falconx_det0\sample103_b_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_b_0001\fluodet_det0\sample103_b_0001.h5
#
#  sample102_t_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_0001\falconx_det0\sample102_t_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_0001\fluodet_det0\sample102_t_0001.h5
#
#  sample102_b_0001
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_b_0001\falconx_det0\sample102_b_0001.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_07_07_SDD_gelatin_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_b_0001\fluodet_det0\sample102_b_0001.h5
#
#  axo_thin_film_c00_0005
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_03_18_SDD_AXO_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\axo_thin_film_c00_0005\falconx_det0\axo_thin_film_c00_0005.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_03_18_SDD_AXO_ls2893_1.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\axo_thin_film_c00_0005\fluodet_det0\axo_thin_film_c00_0005.h5
#
#  sample001_0001
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_04_22_SDD_AXO_ls2893_1_001.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample001_0001\falconx_det0\sample001_0001.h5
# fluodet_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_04_22_SDD_AXO_ls2893_1_001.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample001_0001\fluodet_det0\sample001_0001.h5
#
#  sample001_0003
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_04_22_SDD_AXO_ls2893_1_003.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample001_0003\falconx_det0\sample001_0003.h5
# fluodet_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_04_22_SDD_AXO_ls2893_1_003.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample001_0003\fluodet_det0\sample001_0003.h5
#
#  AXO_thin_film_C00_006_0006
# falconx_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_03_18_SDD_AXO_ls2893_2.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\AXO_thin_film_C00_006_0006\falconx_det0\AXO_thin_film_C00_006_0006.h5
# fluodet_det0 node exists:  True
# 1600
# small dataset z 40 y 40
# spectra shape (1600, 4096)
# reshaped spectra shape (40, 40, 4096)
# spectra config file: 21_03_18_SDD_AXO_ls2893_2.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\AXO_thin_film_C00_006_0006\fluodet_det0\AXO_thin_film_C00_006_0006.h5
#
#  sample304_0013
# falconx_det0 node exists:  True
# 14400
# small dataset z 120 y 120
# spectra shape (14400, 4096)
# reshaped spectra shape (120, 120, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0013\falconx_det0\sample304_0013.h5
# fluodet_det0 node exists:  True
# 14400
# small dataset z 120 y 120
# spectra shape (14400, 4096)
# reshaped spectra shape (120, 120, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0013\fluodet_det0\sample304_0013.h5
#
#  sample304_0016
# falconx_det0 node exists:  True
# 14400
# small dataset z 120 y 120
# spectra shape (14400, 4096)
# reshaped spectra shape (120, 120, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0016\falconx_det0\sample304_0016.h5
# fluodet_det0 node exists:  True
# 14400
# small dataset z 120 y 120
# spectra shape (14400, 4096)
# reshaped spectra shape (120, 120, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0016\fluodet_det0\sample304_0016.h5
#
#  sample304_0017
# falconx_det0 node exists:  True
# 7440
# small dataset z 120 y 62
# spectra shape (7440, 4096)
# reshaped spectra shape (120, 62, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0017\falconx_det0\sample304_0017.h5
# fluodet_det0 node exists:  True
# 7440
# small dataset z 120 y 62
# spectra shape (7440, 4096)
# reshaped spectra shape (120, 62, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0017\fluodet_det0\sample304_0017.h5
#
#  sample304_0018
# falconx_det0 node exists:  True
# 3840
# small dataset z 120 y 32
# spectra shape (3840, 4096)
# reshaped spectra shape (120, 32, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0018\falconx_det0\sample304_0018.h5
# fluodet_det0 node exists:  True
# 3840
# small dataset z 120 y 32
# spectra shape (3840, 4096)
# reshaped spectra shape (120, 32, 4096)
# spectra config file: 21_03_18_SDD_samples_ls2893_2_snip.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0018\fluodet_det0\sample304_0018.h5
#
#  AXO_thin_film_3_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_03_17_GeCMOS_AXO.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\AXO_thin_film_3_0001\falconx_det0\AXO_thin_film_3_0001.h5
# fluodet_det0 node exists:  False
#
#  AXO_thin_film_3_0002
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_03_17_GeCMOS_AXO.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\AXO_thin_film_3_0002\falconx_det0\AXO_thin_film_3_0002.h5
# fluodet_det0 node exists:  False
#
#  AXO_thin_film_3_0003
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_03_17_GeCMOS_AXO.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\AXO_thin_film_3_0003\falconx_det0\AXO_thin_film_3_0003.h5
# fluodet_det0 node exists:  False
#
#  sample102_t_3_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0001\falconx_det0\sample102_t_3_0001.h5
# fluodet_det0 node exists:  False
#
#  sample102_t_3_0002
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0002\falconx_det0\sample102_t_3_0002.h5
# fluodet_det0 node exists:  False
#
#  sample102_t_3_0003
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0003\falconx_det0\sample102_t_3_0003.h5
# fluodet_det0 node exists:  False
#
#  sample102_t_3_0004
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0004\falconx_det0\sample102_t_3_0004.h5
# fluodet_det0 node exists:  False
#
#  sample102_t_3_0005
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0005\falconx_det0\sample102_t_3_0005.h5
# fluodet_det0 node exists:  False
#
#  sample102_t_3_0006
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0006\falconx_det0\sample102_t_3_0006.h5
# fluodet_det0 node exists:  False
#
#  sample103_t_3_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0001\falconx_det0\sample103_t_3_0001.h5
# fluodet_det0 node exists:  False
#
#  sample103_t_3_0002
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0002\falconx_det0\sample103_t_3_0002.h5
# fluodet_det0 node exists:  False
#
#  sample103_t_3_0003
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0003\falconx_det0\sample103_t_3_0003.h5
# fluodet_det0 node exists:  False
#
#  sample103_t_3_0004
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0004\falconx_det0\sample103_t_3_0004.h5
# fluodet_det0 node exists:  False
#
#  sample103_t_3_0005
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0005\falconx_det0\sample103_t_3_0005.h5
# fluodet_det0 node exists:  False
#
#  sample103_t_3_0006
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0006\falconx_det0\sample103_t_3_0006.h5
# fluodet_det0 node exists:  False
#
#  sample105_t_3_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0001\falconx_det0\sample105_t_3_0001.h5
# fluodet_det0 node exists:  False
#
#  sample105_t_3_0002
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0002\falconx_det0\sample105_t_3_0002.h5
# fluodet_det0 node exists:  False
#
#  sample105_t_3_0003
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0003\falconx_det0\sample105_t_3_0003.h5
# fluodet_det0 node exists:  False
#
#  sample105_t_3_0004
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0004\falconx_det0\sample105_t_3_0004.h5
# fluodet_det0 node exists:  False
#
#  sample105_t_3_0005
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0005\falconx_det0\sample105_t_3_0005.h5
# fluodet_det0 node exists:  False
#
#  sample105_t_3_0006
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0006\falconx_det0\sample105_t_3_0006.h5
# fluodet_det0 node exists:  False
#
#  sample107_t_3_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0001\falconx_det0\sample107_t_3_0001.h5
# fluodet_det0 node exists:  False
#
#  sample107_t_3_0002
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0002\falconx_det0\sample107_t_3_0002.h5
# fluodet_det0 node exists:  False
#
#  sample107_t_3_0003
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0003\falconx_det0\sample107_t_3_0003.h5
# fluodet_det0 node exists:  False
#
#  sample107_t_3_0004
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0004\falconx_det0\sample107_t_3_0004.h5
# fluodet_det0 node exists:  False
#
#  sample107_t_3_0005
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0005\falconx_det0\sample107_t_3_0005.h5
# fluodet_det0 node exists:  False
#
#  sample107_t_3_0006
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0006\falconx_det0\sample107_t_3_0006.h5
# fluodet_det0 node exists:  False
#
#  GeCMOS_blank_1000
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\GeCMOS_blank_1000\falconx_det0\GeCMOS_blank_1000.h5
# fluodet_det0 node exists:  False
#
#  GeCMOS_blank_100
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\GeCMOS_blank_100\falconx_det0\GeCMOS_blank_100.h5
# fluodet_det0 node exists:  False
#
#  GeCMOS_blank_10
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 21_07_07_GeCMOS_gelatin.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\GeCMOS_blank_10\falconx_det0\GeCMOS_blank_10.h5
# fluodet_det0 node exists:  False
#
#  sample304_0001
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_05_14_GeCMOS_samples.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0001\falconx_det0\sample304_0001.h5
# fluodet_det0 node exists:  False
#
#  sample304_0002
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_05_14_GeCMOS_samples.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0002\falconx_det0\sample304_0002.h5
# fluodet_det0 node exists:  False
#
#  sample304_b_0001
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_05_14_GeCMOS_samples.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_b_0001\falconx_det0\sample304_b_0001.h5
# fluodet_det0 node exists:  False
#
#  sample304_b_0002
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_05_14_GeCMOS_samples.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_b_0002\falconx_det0\sample304_b_0002.h5
# fluodet_det0 node exists:  False
#
#  sample304_b_0003
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 21_05_14_GeCMOS_samples.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_b_0003\falconx_det0\sample304_b_0003.h5
# fluodet_det0 node exists:  False
#
#  sample304_b_0004
# falconx_det0 node exists:  True
# 23700
# small dataset z 150 y 158
# spectra shape (23700, 4096)
# reshaped spectra shape (150, 158, 4096)
# spectra config file: 21_05_14_GeCMOS_samples.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_b_0004\falconx_det0\sample304_b_0004.h5
# fluodet_det0 node exists:  True
# 0
# fluodet_det0 empty, no fit performed
#
#  st_cp_column2_aglfxd_2_10Hz_0001
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\st_cp_column2_aglfxd_2_10Hz_0001\falconx_det0\st_cp_column2_aglfxd_2_10Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  st_cp_column2_aglfxd_50Hz_0002
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\st_cp_column2_aglfxd_50Hz_0002\falconx_det0\st_cp_column2_aglfxd_50Hz_0002.h5
# fluodet_det0 node exists:  False
#
#  st_cp_column2_angle_250Hz_0002
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\st_cp_column2
hz_0001
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sp_cp_mcf10a_500Hz_0001\falconx_det0\sp_cp_mcf10a_500Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  sp_cp_mcf10a_800Hz_0001
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sp_cp_mcf10a_800Hz_0001\falconx_det0\sp_cp_mcf10a_800Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  sp_cp_mcf10a_1000Hz_0001
# falconx_det0 node exists:  True
# 40000
# small dataset z 200 y 200
# spectra shape (40000, 4096)
# reshaped spectra shape (200, 200, 4096)
# spectra config file: 220207_snip22.cfg
# ...
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\g192_500Hz_0001\falconx_det0\g192_500Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  g192_800Hz_0002
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\g192_800Hz_0002\falconx_det0\g192_800Hz_0002.h5
# fluodet_det0 node exists:  False
#
#  g192_1000Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\g192_1000Hz_0001\falconx_det0\g192_1000Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  g194_10Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\g194_10Hz_0001\falconx_det0\g194_10Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  g194_50Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\g194_50Hz_0001\falconx_det0\g194_50Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  g194_250Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\g194_250Hz_0001\falconx_det0\g194_250Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  g194_500Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\g194_500Hz_0001\falconx_det0\g194_500Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  g194_800Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\g194_800Hz_0001\falconx_det0\g194_800Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  g194_1000Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\g194_1000Hz_0001\falconx_det0\g194_1000Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_tower_10Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_10Hz_0001\falconx_det0\blank_tower_10Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_tower_50Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_50Hz_0001\falconx_det0\blank_tower_50Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_tower_250Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_250Hz_0001\falconx_det0\blank_tower_250Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_tower_500Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_500Hz_0001\falconx_det0\blank_tower_500Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_tower_800Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_800Hz_0001\falconx_det0\blank_tower_800Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_tower_1000Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_1000Hz_0001\falconx_det0\blank_tower_1000Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_env_10Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_10Hz_0001\falconx_det0\blank_env_10Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_env_50Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_50Hz_0001\falconx_det0\blank_env_50Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_env_250Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_250Hz_0001\falconx_det0\blank_env_250Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_env_500Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_500Hz_0001\falconx_det0\blank_env_500Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_env_800Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_800Hz_0001\falconx_det0\blank_env_800Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  blank_env_1000Hz_0001
# falconx_det0 node exists:  True
# 400
# small dataset z 20 y 20
# spectra shape (400, 4096)
# reshaped spectra shape (20, 20, 4096)
# spectra config file: 220207_snip22.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_1000Hz_0001\falconx_det0\blank_env_1000Hz_0001.h5
# fluodet_det0 node exists:  False
#
#  appendix_a1_overview_solid_0002
# falconx_det0 node exists:  True
# 1562500
# small dataset z 1250 y 1250
# spectra shape (1562500, 4096)
# reshaped spectra shape (1250, 1250, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\appendix_a1_overview_solid_0002\falconx_det0\appendix_a1_overview_solid_0002.h5
# fluodet_det0 node exists:  False
#
#  appendix_a1_ROI_solid_0001
# falconx_det0 node exists:  True
# 960000
# small dataset z 800 y 1200
# spectra shape (960000, 4096)
# reshaped spectra shape (800, 1200, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\appendix_a1_ROI_solid_0001\falconx_det0\appendix_a1_ROI_solid_0001.h5
# fluodet_det0 node exists:  False
#
#  tonsil_t1_overview_solid_0001
# falconx_det0 node exists:  True
# 1562500
# small dataset z 1250 y 1250
# spectra shape (1562500, 4096)
# reshaped spectra shape (1250, 1250, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\tonsil_t1_overview_solid_0001\falconx_det0\tonsil_t1_overview_solid_0001.h5
# fluodet_det0 node exists:  False
#
#  tonsil_t1_ROI_solid_0001
# falconx_det0 node exists:  True
# 640000
# small dataset z 800 y 800
# spectra shape (640000, 4096)
# reshaped spectra shape (800, 800, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\tonsil_t1_ROI_solid_0001\falconx_det0\tonsil_t1_ROI_solid_0001.h5
# fluodet_det0 node exists:  False
#
#  breast_cancer_b2_solid_overview_0corrected_0003
# falconx_det0 node exists:  True
# 6250000
# large dataset z 2500 y 2500
# Chunks: 10
# [[0, 625000], [625000, 1250000], [1250000, 1875000], [1875000, 2500000], [2500000, 3125000], [3125000, 3750000], [3750000, 4375000], [4375000, 5000000], [5000000, 5625000], [5625000, 6250000]]
# Deconvoluting spectral chunk: [0, 625000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_0\breast_cancer_b2_solid_overview_0corrected_0003.h5
# Deconvoluting spectral chunk: [625000, 1250000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_1\breast_cancer_b2_solid_overview_0corrected_0003.h5
# Deconvoluting spectral chunk: [1250000, 1875000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_2\breast_cancer_b2_solid_overview_0corrected_0003.h5
# Deconvoluting spectral chunk: [1875000, 2500000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_3\breast_cancer_b2_solid_overview_0corrected_0003.h5
# Deconvoluting spectral chunk: [2500000, 3125000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_4\breast_cancer_b2_solid_overview_0corrected_0003.h5
# Deconvoluting spectral chunk: [3125000, 3750000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_5\breast_cancer_b2_solid_overview_0corrected_0003.h5
# Deconvoluting spectral chunk: [3750000, 4375000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_6\breast_cancer_b2_solid_overview_0corrected_0003.h5
# Deconvoluting spectral chunk: [4375000, 5000000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_7\breast_cancer_b2_solid_overview_0corrected_0003.h5
# Deconvoluting spectral chunk: [5000000, 5625000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_8\breast_cancer_b2_solid_overview_0corrected_0003.h5
# Deconvoluting spectral chunk: [5625000, 6250000]
# spectra shape (625000, 4096)
# reshaped spectra shape (250, 2500, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\chunk_9\breast_cancer_b2_solid_overview_0corrected_0003.h5
# fluodet_det0 node exists:  False
#
#  breast_cancer_b2_ROI_solid_ROI_0001
# falconx_det0 node exists:  True
# 22500
# small dataset z 150 y 150
# spectra shape (22500, 4096)
# reshaped spectra shape (150, 150, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_ROI_solid_ROI_0001\falconx_det0\breast_cancer_b2_ROI_solid_ROI_0001.h5
# fluodet_det0 node exists:  False
#
#  breast_cancer_b2_ROI_solid_0003
# falconx_det0 node exists:  True
# 640000
# small dataset z 800 y 800
# spectra shape (640000, 4096)
# reshaped spectra shape (800, 800, 4096)
# spectra config file: 221217_snip23_esrf2022.cfg
# output hdf file: C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_ROI_solid_0003\falconx_det0\breast_cancer_b2_ROI_solid_0003.h5
# fluodet_det0 node exists:  False
#
#  All files processed

# %% [markdown]
# ## Concatenate chunked deconvolutions

# %%
# ID chunked deconvolutions
chunk_subdirs = list(out_dir.glob('*/*/*/chunk*'))
chunk_dirs = list(np.unique([i.parent for i in chunk_subdirs]))

# Find first hdf and copy to expected location
for chunk_dir in chunk_dirs:
    print(chunk_dir.parent.stem)

    # Identify chunks and concatenate
    hdf_chunks = list(chunk_dir.glob('*/*.h5'))    
    for i, hdf_chunk in enumerate(hdf_chunks[:]):
        if i == 0:
            hdf_base_path = chunk_dir / hdf_chunks[0].name
            shutil.copyfile(hdf_chunks[0], hdf_base_path) 
        else:
            print(hdf_chunk.parent.stem)
            with h5py.File(hdf_base_path, 'a') as hdf_base:
                with h5py.File(hdf_chunk, 'r') as hdf_add:
                    node = f"{hdf_base_path.stem}/plotselect"
                    for plot in hdf_base[node].keys():
                        subnode = f"{node}/{plot}"
                        array_top = hdf_base[subnode][:]
                        array_base = hdf_add[subnode][:]
                        array_stacked = np.concatenate([array_top, array_base], axis=0)
                        
                        del hdf_base[subnode]
                        hdf_base.create_dataset(subnode, data=array_stacked)
                        
    # Extract tifs from hdf channels
    with h5py.File(hdf_base_path, 'r+') as hdf:
        image_dir = hdf_base_path.parent / "IMAGES"
        image_dir.mkdir(parents=True, exist_ok=True)
        
        for img in hdf[node].keys():
            subnode = f"{node}/{img}"
            dset = hdf[subnode][:]
            outpath = str(image_dir / f'{img}.tiff')
            cv2.imwrite(outpath, dset)
# Out:
# breast_cancer_b2_solid_overview_0corrected_0003
# chunk_1
# chunk_2
# chunk_3
# chunk_4
# chunk_5
# chunk_6
# chunk_7
# chunk_8
# chunk_9

# %% [markdown]
#  Incorporate step sizes for final channel image hdf files.

# %%
# Incorporate key csv attributes per scan to deconvoluted hdfs for subsequent analysis
# hdf_img_fpaths = [i for i in out_dir.glob('*/*/*/*.h5')]
hdf_img_fpaths = [f"{hdf_file}.h5" for hdf_file in df_hdf_config['hdf_file']]
list(out_dir.glob(f"*/*/*/{hdf_img_fpaths[0]}"))[0]
hdf_img_fpaths = [list(out_dir.glob(f"*/*/*/{hdf_file}"))[0] for hdf_file in hdf_img_fpaths]

for hdf_img_fpath in hdf_img_fpaths:
    print(hdf_img_fpath)
    step = df_hdf_config.loc[df_hdf_config['hdf_file'] == hdf_img_fpath.stem, 'step_um'].iloc[0]
    det_type = df_hdf_config.loc[df_hdf_config['hdf_file'] == hdf_img_fpath.stem, 'detector'].iloc[0]
    dual_det = df_hdf_config.loc[df_hdf_config['hdf_file'] == hdf_img_fpath.stem, 'dual_detector'].iloc[0]
    
    if dual_det == 1:
        dual_det = 'yes'
    else:
        dual_det = 'no'
   
    with h5py.File(hdf_img_fpath, 'a') as hdf:
        if 'pixel_um' in hdf:
            pass 
        else:
            hdf.create_dataset(name = 'pixel_um', data = step)
        if 'detector' in hdf:
            print('detector in hdf, overwriting')
            del hdf['detector']
            hdf.create_dataset('detector', data=det_type)
        else:
            print('detector not in hdf, creating')
            hdf.create_dataset(name = 'detector', data = det_type)
        if 'dual_detector' in hdf:
            pass 
        else:
            hdf.create_dataset(name = 'dual_detector', data = dual_det)

print('Key acquisition metadata incorporated to .hdf files')
# Out:
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\001_002_stitch\falconx_det0\001_002_stitch.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\001_004_stitch\falconx_det0\001_004_stitch.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\304_007_stitch\falconx_det0\304_007_stitch.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\304_009_stitch\falconx_det0\304_009_stitch.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample191_0001\falconx_det0\sample191_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\mylar_0001\falconx_det0\mylar_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_0001\falconx_det0\sample107_t_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_b_0001\falconx_det0\sample107_b_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_0001\falconx_det0\sample105_t_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_b_0001\falconx_det0\sample105_b_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_0001\falconx_det0\sample103_t_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_b_0001\falconx_det0\sample103_b_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_0001\falconx_det0\sample102_t_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_b_0001\falconx_det0\sample102_b_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\axo_thin_film_c00_0005\falconx_det0\axo_thin_film_c00_0005.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample001_0001\falconx_det0\sample001_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample001_0003\falconx_det0\sample001_0003.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\AXO_thin_film_C00_006_0006\falconx_det0\AXO_thin_film_C00_006_0006.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0013\falconx_det0\sample304_0013.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0016\falconx_det0\sample304_0016.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0017\falconx_det0\sample304_0017.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0018\falconx_det0\sample304_0018.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\AXO_thin_film_3_0001\falconx_det0\AXO_thin_film_3_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\AXO_thin_film_3_0002\falconx_det0\AXO_thin_film_3_0002.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\AXO_thin_film_3_0003\falconx_det0\AXO_thin_film_3_0003.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0001\falconx_det0\sample102_t_3_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0002\falconx_det0\sample102_t_3_0002.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0003\falconx_det0\sample102_t_3_0003.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0004\falconx_det0\sample102_t_3_0004.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0005\falconx_det0\sample102_t_3_0005.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample102_t_3_0006\falconx_det0\sample102_t_3_0006.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0001\falconx_det0\sample103_t_3_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0002\falconx_det0\sample103_t_3_0002.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0003\falconx_det0\sample103_t_3_0003.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0004\falconx_det0\sample103_t_3_0004.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0005\falconx_det0\sample103_t_3_0005.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample103_t_3_0006\falconx_det0\sample103_t_3_0006.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0001\falconx_det0\sample105_t_3_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0002\falconx_det0\sample105_t_3_0002.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0003\falconx_det0\sample105_t_3_0003.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0004\falconx_det0\sample105_t_3_0004.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0005\falconx_det0\sample105_t_3_0005.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample105_t_3_0006\falconx_det0\sample105_t_3_0006.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0001\falconx_det0\sample107_t_3_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0002\falconx_det0\sample107_t_3_0002.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0003\falconx_det0\sample107_t_3_0003.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0004\falconx_det0\sample107_t_3_0004.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0005\falconx_det0\sample107_t_3_0005.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample107_t_3_0006\falconx_det0\sample107_t_3_0006.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\GeCMOS_blank_1000\falconx_det0\GeCMOS_blank_1000.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\GeCMOS_blank_100\falconx_det0\GeCMOS_blank_100.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\GeCMOS_blank_10\falconx_det0\GeCMOS_blank_10.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0001\falconx_det0\sample304_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_0002\falconx_det0\sample304_0002.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304_b_0001\falconx_det0\sample304_b_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\sample304
10Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_50Hz_0001\falconx_det0\blank_tower_50Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_250Hz_0001\falconx_det0\blank_tower_250Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_500Hz_0001\falconx_det0\blank_tower_500Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_800Hz_0001\falconx_det0\blank_tower_800Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_tower_1000Hz_0001\falconx_det0\blank_tower_1000Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_10Hz_0001\falconx_det0\blank_env_10Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_50Hz_0001\falconx_det0\blank_env_50Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_250Hz_0001\falconx_det0\blank_env_250Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_500Hz_0001\falconx_det0\blank_env_500Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_800Hz_0001\falconx_det0\blank_env_800Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\blank_env_1000Hz_0001\falconx_det0\blank_env_1000Hz_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\appendix_a1_overview_solid_0002\falconx_det0\appendix_a1_overview_solid_0002.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\appendix_a1_ROI_solid_0001\falconx_det0\appendix_a1_ROI_solid_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\tonsil_t1_overview_solid_0001\falconx_det0\tonsil_t1_overview_solid_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\tonsil_t1_ROI_solid_0001\falconx_det0\tonsil_t1_ROI_solid_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_solid_overview_0corrected_0003\falconx_det0\breast_cancer_b2_solid_overview_0corrected_0003.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_ROI_solid_ROI_0001\falconx_det0\breast_cancer_b2_ROI_solid_ROI_0001.h5
# detector not in hdf, creating
# C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\per_detector_deconvolutions\breast_cancer_b2_ROI_solid_0003\falconx_det0\breast_cancer_b2_ROI_solid_0003.h5
# detector not in hdf, creating
# Key acquisition metadata incorporated to .hdf files

# %% [markdown]
# Collate hdfs to summary hdfs per sample. For scans with dual detectors, element plots will be aggregated, while for single detector scans these will simply be copied over.

# %%
detector_paths = ['falconx_det0', 'fluodet_det0']
out_sum_dir = out_dir / 'summary_hdfs'
out_sum_dir.mkdir(parents=True, exist_ok=True)

# Copy the falconX detector to summary scan output
for hdf_file in df_hdf_config['hdf_file']:
    hdf_dir = out_dir / 'per_detector_deconvolutions' / hdf_file 
    hdf_fpath = list(hdf_dir.glob('*/*.h5'))
    
    shutil.copyfile(hdf_fpath[0], out_sum_dir / hdf_fpath[0].name)
            
# For dual detector scans, modify the summary scan datasets by aggregating second detector data for plots
for hdf_file in df_hdf_config.loc[df_hdf_config['dual_detector'] == 1, 'hdf_file']:
    hdf_dir = out_dir / 'per_detector_deconvolutions' / hdf_file 
    hdf_fpath = list(hdf_dir.glob('*/*.h5'))
    
    hdf_base = h5py.File(hdf_fpath[0], 'r+')
    plots = list(hdf_base[f'{hdf_file}/plotselect'].keys())
    
    for plot in plots:
        dset = hdf_base[f'{hdf_file}/plotselect/{plot}'][:]
        
        with h5py.File(hdf_fpath[1], 'r+') as hdf_add:
            dset_add = hdf_add[f'{hdf_file}/plotselect/{plot}'][:]
            
        dset_mean = np.mean([dset, dset_add], axis=0)
        
        hdf_mod_path = out_sum_dir / hdf_fpath[0].name
        #print(hdf_mod_path.exists())
        with h5py.File(hdf_mod_path, 'r+') as hdf_mod:
            hdf_mod[f'{hdf_file}/plotselect/{plot}'][...] = dset_mean
        
    #print(dset_mean.shape) 
    hdf_base.close()
    
print('Summary hdfs output to: ', out_sum_dir)
# Out:
# Summary hdfs output to:  C:\Users\MerrickS\OneDrive\Work\2_UZH\Papers\1_MEZ_XRF\data\processed\xrf\2_deconvoluted_hdfs\summary_hdfs
